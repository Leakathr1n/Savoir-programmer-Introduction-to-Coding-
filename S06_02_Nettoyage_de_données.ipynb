# %% [markdown]
# # Normaliser les données pour de meilleures analyses
#
# Il est très rare que les ensembles de données que vous aurez à manipuler soient impeccables. En effet, même lors les données sont produites automatiquement par des systèmes informatiques, il est possible que ces données contiennent des erreurs. Ces erreurs peuvent être causées par une défaillance du système, par une interruption du réseau, etc.
#
# Imaginez alors les erreurs qui peuvent s'introduirent lorsque l'humain est en cause! Même dans le cas idéal où un seul individu s'occupe de la saisie des données, il n'est pas exclus que cet individu introduisent (sic) des erreurs. Cela augmente de façon très rapide lorsque plusieurs individus s'occupent de la saisie.
#
# La normalisation des données est donc souvent nécessaire pour une analyse adéquate. Nous allons maintenant explorer comment les approches de normalisation peuvent être mise en application. Pour appliquer ces approches, nous utiliserons les données contenues dans le fichier `Connections.csv`, contenant un exemple de données provenant de LinkedIn, afin d'explorer quelques-unes des situations courantes que vous pouvez rencontrer pendant le traitement des données.
#
# ## Lecture d'un fichier de données
#
# Mais avant de procéder à la normalisation des données, il faut extraire ces données du fichier source et les placer en mémoire dans un format adéquat pour l'analyse. L'objectif final est d'avoir une collection de liste, chaque liste correspondant à une caractéristique d'un contact LinkedIn. C'est comme avoir une feuille de travail Excel où les données sont organisés en tableau individu x caractéristiques:
#
# - les individus sont les lignes du chiffrier Excel,
# - les caractéristiques sont les colonnes.
#
# Pour produire une structure de données similaire en Python, on utilisera une collection de liste, chaque liste correspondant à une colonne. Les données sur un individu spécifique se retrouvera à la même position dans chacune des listes. On dira que ces listes sont des __listes parallèles__.
#
# Dans un premier temps, nous allons simplement lire toutes les lignes du fichier de telle façon que chaque ligne soit un élément de la liste `connexions`. Pour voir à quoi ces données ressemblent, nous afficherons les 5 premières et les 5 dernières lignes de la liste ainsi obtenue.

# %%
# Création d'une liste vide
connexions = []

# Ouverture du fichier "Connections.csv"
# encoding="utf-8" : puisque les données contiennent des caractères spéciaux (à, è, ù, etc.)
with open("Connections.csv", "r", encoding="utf-8") as file: #file represent les variables
    
    # Lecture des lignes et assignation à la liste 'connexions'
    connexions = file.readlines()
    
    print(connexions) #back the \n
    connexions #avec \n
# Out:
# ['"First Name","Last Name","Email Address","Company","Position","Connected On"\n', '"Mélanie","Dénommée","","Essilor Canada","Chef Partenariat d\'affaires RH/HRBP Manager","17-sept-18"\n', '"Justine","Authier, MSc","","HEC Montréal","Lecturer | Database Management Course","28-mars-18"\n', '"Elodie","Champoux","","CBC","Première Analyste Intelligence d\'Affaires | Senior Business Intelligence Analyst ","27-mars-18"\n', '"Jean","Talbot","","HEC Montreal","Professeur titulaire / Full Professor","19-juin-17"\n', '"Karsten","Herr","","Darling Ingredients Germany Holding GmbH","Technical Director Germany/CTO","15-juin-16"\n', '"Mina","Rohani","","Key Lime Interactive","UX Researcher @ Google + Senior Quantitative Researcher @ KLI","07-janv-15"\n', '"Markos","Zachariadis","","Ivey Business School at Western University","Visiting Professor/Faculty in Financial Technologies (FinTech)","09 May 2014"\n', '"Anne","Chartier","","Université Laval","Associate professor / Professeure agrégée","30-janv-14"\n', '"Jean-François","Brodeur","","Collège de Bois-de-Boulogne","Enseignant département d\'informatique / Teacher","16-oct-13"\n', '"Eric","Segal, MD, MSc, BCom, BSc","","CIUSSS de l\'Estrie - CHUS","Resident Physician / Médecin Résident","26 May 2012"\n', '"Razvan","Radulian","","Why-What-How Consulting, LLC","Independent Consultant/Owner","06 Apr 2012"\n', '"Augustin","Bilolo","","Banque Nationale","Senior Analyst / Developer IBM WebSphere Portal","25 Aug 2010"\n', '"Ben","Breiner","","Amgen","Executive Biopharmaceutical Representative - Rheumatology/Dermatology","25 Apr 2008"\n', '"Nita","Hayre","","Warwick Business School","Group Coordinator","02-juil-19"\n', '"Don","MacLean","","HEC Montréal","Doctoral Candidate","12 May 2019"\n', '"Karim","Emond","","National Research Council Canada / Conseil national de recherches Canada","Data Scientist","09 Apr 2019"\n', '"Charlotte","Blanche","","HEC Montréal","Chargée de cours - Management Interculturel","04 Apr 2019"\n', '"Paul","Ranson (MBA)","","University of Wales Trinity Saint David","Visiting Lecturer","28 Feb 2019"\n', '"Tuba","Tuncel","","Toulouse School of Economics","Phd Candidate","04 Feb 2019"\n', '"Haris","Krijestorac","","ProdamSam.com","Web Strategist, Partner","28-janv-19"\n', '"John","Wade","","Creative Destruction Lab - Montreal","Venture Recruiter","01-nov-18"\n', '"Audrey","Leduc","","Breathe Life","Projet supervisé de maîtrise - science des données","31-oct-18"\n', '"Asif","Ansari, MBA","","TELUS Business","Product Manager","30-oct-18"\n', '"Peter","Bachour","","IBM Client Innovation Center Montreal","Business Transformation Consultant: Talent & Mobilisation","24-oct-18"\n', '"José A.","Cofré","","Olam","Head of Legal, Europe","21-oct-18"\n', '"Rachel","Cook","","Lumesse","Head of Business Transformation","04-sept-18"\n', '"Gilbert","Babin","","HEC Montréal","Director, Department of Information Technologies","20 Aug 2018"\n', '"Ralph","Smyth","","Highways England","Member of Strategic Design Panel","14 Aug 2018"\n', '"Asha","Ginda","","University of Warwick - Warwick Business School","Deputy Programmes Manager","30-juil-18"\n', '"Leen","Issa","","Microsoft","MBA Consultancy Project","29-juin-18"\n', '"Ryad","Titah","","EM Lyon","Associate Professor","27-juin-18"\n', '"Louise","Welch MBA","","PlayStation Europe","Director of Supply Chain Planning","24-juin-18"\n', '"James","Barber MBA","","VALUE RETAIL MANAGEMENT LIMITED","Risk and Compliance Director","24-juin-18"\n', '"Olena","Bezkokotova","","Transport for London","Head of Customer Operations","08-juin-18"\n', '"Mehdi","Lahlou","","Mehdi Lahlou","Formateur et consultant en TI","17 May 2018"\n', '"Alice","Lake","","Atos","Incoming Graduate Cyber Security Engineer","11 May 2018"\n', '"Lamiel","Brasseur","","HEC Montréal","Directrice - Direction de l\'apprentissage et de l\'innovation pédagogique","10 May 2018"\n', '"Mary-Sarah","Gagnon, MBA","","Ubisoft Montréal","Marketing Data Analyst, E-Commerce","07 May 2018"\n', '"Marine" ...

# %% [markdown]
# Avons-nous réussi à lire correctement le fichier texte et à stocker les données dans la variable liste `connexions` ?

# %%
# impression des 5 premières lignes
for i in range(0, 5):
    print(connexions[i])

# Impression de ...
print("...")
print()
# Impression des 5 dernières lignes
for i in range(-5, 0 ):
    print(connexions[i])
# Out:
# "First Name","Last Name","Email Address","Company","Position","Connected On"
#
# "Mélanie","Dénommée","","Essilor Canada","Chef Partenariat d'affaires RH/HRBP Manager","17-sept-18"
#
# "Justine","Authier, MSc","","HEC Montréal","Lecturer | Database Management Course","28-mars-18"
#
# "Elodie","Champoux","","CBC","Première Analyste Intelligence d'Affaires | Senior Business Intelligence Analyst ","27-mars-18"
#
# "Jean","Talbot","","HEC Montreal","Professeur titulaire / Full Professor","19-juin-17"
#
# ...
#
# "Albina","Shapiro","","SAP Labs","Product Owner","17 Feb 2007"
#
# "Sydney","Vasseur","","Gemini Data Inc.","Business Development Representative EMEA","24-nov-16"
#
# "Brian","Lack","","Simply Voting Inc.","President","15 Dec 2011"
#
# "Nolwen","Mahé","","Alsago Inc.","Consultant, Agile governance","02 Dec 2011"
#
# "Marlene","Newton","","Informatique Newton Inc.","Senior Project Manager","11-juin-09"

# %% [markdown]
# __En regardant le contenu de chaque ligne, on constate que__ :
#
# 1. Chaque ligne se termine par le caractère spécial `\n`. Ceci se voit parce qu'il y a une ligne vide entre chaque exécution de la commande `print()`. On pourrait mieux le voir si on affichait une *slice* des 5 premiers éléments. On verra alors à la fin de chaque élément le caractère de fin de ligne (`\n`).

# %%
# Impression des 5 premiers éléments de la liste 'connexions'
print(connexions[0:5])
# Out:
# ['\ufeff"First Name","Last Name","Email Address","Company","Position","Connected On"\n', '"Mélanie","Dénommée","","Essilor Canada","Chef Partenariat d\'affaires RH/HRBP Manager","17-sept-18"\n', '"Justine","Authier, MSc","","HEC Montréal","Lecturer | Database Management Course","28-mars-18"\n', '"Elodie","Champoux","","CBC","Première Analyste Intelligence d\'Affaires | Senior Business Intelligence Analyst ","27-mars-18"\n', '"Jean","Talbot","","HEC Montreal","Professeur titulaire / Full Professor","19-juin-17"\n']

# %% [markdown]
# 2. Chaque ligne contient les données correspondant à un contact.
# 3. Il y a des blocs de texte séparés par des virgules. Par exemple `"Mélanie","Dénommée","","Essilor Canada ",` etc. Chaque bloc correspond à une caractéristique d'un contact.
# 4. La première ligne (`connexions[0]`) contient les noms de ces caractéristiques: *First Name*, *Last Name*, *Email Address*, *Company*, *Position* et *Connected On*.

# %%
# Impression du premier élément de la liste 'connexions'
print(connexions[0])
# Out:
# ﻿"First Name","Last Name","Email Address","Company","Position","Connected On"

# %% [markdown]
# Comme nous l'avons indiqué précédemment, on voudra que chacun de ces blocs de données soit mémorisé dans une liste, un peu comme chaque caractéristique serait dans une colonne séparée dans Excel. Voyons donc à quoi nos données ressemblerait si on séparait le contenu des lignes à chaque virgule.
#
# - On utilisera la méthode `strip()` pour supprimer les caractères invisibles (les espaces, les tabulations `\t` et les fins de ligne `\n`) aux extrémités de la ligne.
# - On suivra par la commande `split()` pour obtenir la liste des blocs contenus dans une ligne.
#
# Comme il y a 6 noms de blocs dans la première ligne (`"First Name", "Last Name", "Email Address", "Company", "Position", "Connected On"`), on s'attend donc à ce que chaque liste ainsi produite ait aussi 6 éléments. Voyons ce qui se produit si nous effectuons cette transformation et validons que le résultat est une liste de 6 éléments. Pour cette validation nous n'afficherons que l'index des lignes où le nombre de colonnes n'est pas 6.

# %%
# On découpe chaque ligne, ***sauf la première*** qui se trouve à l'index 0
for i in range(1, len(connexions)):
    
    # On enlève les caractères superflus et on découpe autour des virgules
    data = connexions[i].strip().split("\",\"") #on put faire '","' aussi mais pas "",""
    #strip: get rid of \n
    #split: pour ,
    
    # Si la liste 'data' ne contient pas 6 éléments, on affiche le nombre d'éléments
    # et l'index de la ligne
    if (len(data) != 6):
        print("{0} colonnes : index {1}".format(len(data), i))
        
data[0][1:]
data [5][:-1]
# Out:
# '11-juin-09'

# %% [markdown]
# On voit donc que la séparation sur la virgule `split(",")` ne donne pas le bon résultat, car __plusieurs lignes produisent plus de 6 colonnes__. Pourquoi est-ce le cas ?
#
# Observons plus en détails une des lignes donnant le mauvais résultat.

# %%
# On imprime la première ligne qui n'a pas 6 éléments
print(connexions[2])
# Out:
# "Justine","Authier, MSc","","HEC Montréal","Lecturer | Database Management Course","28-mars-18"

# %% [markdown]
# On constate que le deuxième bloc de texte contient lui-même une virgule! On ne pourra donc pas simplement utiliser la virgule comme séparateur. Par contre, en observant les données un peu plus en détails, on voit que chaque bloc est encadré par un guillemet (`"`). Il serait donc plus robuste de faire la séparation avec la séquence `","`.

# %%
# On découpe chaque ligne, ***sauf la première*** qui se trouve à l'index 0
for i in range(1, len(connexions)):
    
    # On enlève les caractères superflus et on découpe autour de la séquence de caractères ","
    data = connexions[i].strip().split('","')
    
    # Si la liste ne contient pas 6 éléments, on affiche le nombre d'éléments et l'index de la ligne
    if (len(data) != 6):
        print("{0} colonnes : index {1}".format(len(data), i))

# %% [markdown]
# Effectivement, cela règle le problème du nombre de blocs. Cependant, cela ne règle pas tous les problèmes. Regardons en détails le contenu de chaque liste (correspondant à chaque ligne du fichier).

# %%
# On découpe chaque ligne, ***sauf la première*** qui se trouve à l'index 0
for i in range(1, len(connexions)):
    
    # On enlève les caractères superflus et on découpe autour de la séquence de caractères ","
    data = connexions[i].strip().split('","')
    
    # On affiche la liste résultante
    print(data)
# Out:
# ['"Mélanie', 'Dénommée', '', 'Essilor Canada', "Chef Partenariat d'affaires RH/HRBP Manager", '17-sept-18"']
# ['"Justine', 'Authier, MSc', '', 'HEC Montréal', 'Lecturer | Database Management Course', '28-mars-18"']
# ['"Elodie', 'Champoux', '', 'CBC', "Première Analyste Intelligence d'Affaires | Senior Business Intelligence Analyst ", '27-mars-18"']
# ['"Jean', 'Talbot', '', 'HEC Montreal', 'Professeur titulaire / Full Professor', '19-juin-17"']
# ['"Karsten', 'Herr', '', 'Darling Ingredients Germany Holding GmbH', 'Technical Director Germany/CTO', '15-juin-16"']
# ['"Mina', 'Rohani', '', 'Key Lime Interactive', 'UX Researcher @ Google + Senior Quantitative Researcher @ KLI', '07-janv-15"']
# ['"Markos', 'Zachariadis', '', 'Ivey Business School at Western University', 'Visiting Professor/Faculty in Financial Technologies (FinTech)', '09 May 2014"']
# ['"Anne', 'Chartier', '', 'Université Laval', 'Associate professor / Professeure agrégée', '30-janv-14"']
# ['"Jean-François', 'Brodeur', '', 'Collège de Bois-de-Boulogne', "Enseignant département d'informatique / Teacher", '16-oct-13"']
# ['"Eric', 'Segal, MD, MSc, BCom, BSc', '', "CIUSSS de l'Estrie - CHUS", 'Resident Physician / Médecin Résident', '26 May 2012"']
# ['"Razvan', 'Radulian', '', 'Why-What-How Consulting, LLC', 'Independent Consultant/Owner', '06 Apr 2012"']
# ['"Augustin', 'Bilolo', '', 'Banque Nationale', 'Senior Analyst / Developer IBM WebSphere Portal', '25 Aug 2010"']
# ['"Ben', 'Breiner', '', 'Amgen', 'Executive Biopharmaceutical Representative - Rheumatology/Dermatology', '25 Apr 2008"']
# ['"Nita', 'Hayre', '', 'Warwick Business School', 'Group Coordinator', '02-juil-19"']
# ['"Don', 'MacLean', '', 'HEC Montréal', 'Doctoral Candidate', '12 May 2019"']
# ['"Karim', 'Emond', '', 'National Research Council Canada / Conseil national de recherches Canada', 'Data Scientist', '09 Apr 2019"']
# ['"Charlotte', 'Blanche', '', 'HEC Montréal', 'Chargée de cours - Management Interculturel', '04 Apr 2019"']
# ['"Paul', 'Ranson (MBA)', '', 'University of Wales Trinity Saint David', 'Visiting Lecturer', '28 Feb 2019"']
# ['"Tuba', 'Tuncel', '', 'Toulouse School of Economics', 'Phd Candidate', '04 Feb 2019"']
# ['"Haris', 'Krijestorac', '', 'ProdamSam.com', 'Web Strategist, Partner', '28-janv-19"']
# ['"John', 'Wade', '', 'Creative Destruction Lab - Montreal', 'Venture Recruiter', '01-nov-18"']
# ['"Audrey', 'Leduc', '', 'Breathe Life', 'Projet supervisé de maîtrise - science des données', '31-oct-18"']
# ['"Asif', 'Ansari, MBA', '', 'TELUS Business', 'Product Manager', '30-oct-18"']
# ['"Peter', 'Bachour', '', 'IBM Client Innovation Center Montreal', 'Business Transformation Consultant: Talent & Mobilisation', '24-oct-18"']
# ['"José A.', 'Cofré', '', 'Olam', 'Head of Legal, Europe', '21-oct-18"']
# ['"Rachel', 'Cook', '', 'Lumesse', 'Head of Business Transformation', '04-sept-18"']
# ['"Gilbert', 'Babin', '', 'HEC Montréal', 'Director, Department of Information Technologies', '20 Aug 2018"']
# ['"Ralph', 'Smyth', '', 'Highways England', 'Member of Strategic Design Panel', '14 Aug 2018"']
# ['"Asha', 'Ginda', '', 'University of Warwick - Warwick Business School', 'Deputy Programmes Manager', '30-juil-18"']
# ['"Leen', 'Issa', '', 'Microsoft', 'MBA Consultancy Project', '29-juin-18"']
# ['"Ryad', 'Titah', '', 'EM Lyon', 'Associate Professor', '27-juin-18"']
# ['"Louise', 'Welch MBA', '', 'PlayStation Europe', 'Director of Supply Chain Planning', '24-juin-18"']
# ['"James', 'Barber MBA', '', 'VALUE RETAIL MANAGEMENT LIMITED', 'Risk and Compliance Director', '24-juin-18"']
# ['"Olena', 'Bezkokotova', '', 'Transport for London', 'Head of Customer Operations', '08-juin-18"']
# ['"Mehdi', 'Lahlou', '', 'Mehdi Lahlou', 'Formateur et consultant en TI', '17 May 2018"']
# ['"Alice', 'Lake', '', 'Atos', 'Incoming Graduate Cyber Security Engineer', '11 May 2018"']
# ['"Lamiel', 'Brasseur', '', 'HEC Montréal', "Directrice - Direction de l'apprentissage et de l'innovation pédagogique", '10 May 2018"']
# ['"Mary-Sarah', 'Gagnon, MBA', '', 'Ubisoft Montréal', 'Marketing Data Analyst, E-Commerce', '07 May 2018"']
# ['"Marine', 'Avedissian', '', 'Banque Nationale', 'Stagiaire en analytique, AI & Marketing', '05 May 2018"']
# ['"Robert Wayne', 'Gregory', '', 'University of Virginia', 'Associate Professor', '03 May 2018"']
# ['"Joé', 'Martineau', '', 'HEC Montréal', 'Assistant Professor', '13 Apr 2018"']
# ['"Me Nancy', "O'Connor", '', "O'Connor Notaire et conseiller juridique", 'Notaire, conseillère juridique et médiatrice engagée', '04 Apr 2018"']
# ['"Hassen', 'Bouacida', '', 'Desjardins', 'Conseiller Principal - Personnalisation des cartes', '16-mars-18"']
# ['"Daphne', 'Coates', '', 'IBM', 'Watson IoT and Industry 4.0 Consultant', '14-mars-18"']
# ['"Zishu', 'Zhao', '', 'IBM iX', 'Technology Consymtant', '11-mars-18"']
# ['"Mayur P.', 'Joshi', '', 'HDFC Bank', 'Sub Unit Head- Retail Branch Control Unit, Corporate Office,', '09-mars-18"']
# ['"Sylvia', 'Santosa', '', 'International Journal of Obesity', 'Editorial Board Member', '20 Feb 2018"']
# ['"Alain', 'Elkaim', '', 'HEC Montreal', 'Trading room manager', '15 Feb 2018"']
# ['"Sheila', 'Tran', '', 'IN-RGY (Digital transformation consulting firm)', 'Kronos Junior Consultant', '09 Feb 2018"']
# ['"Rakhimé', 'Abdul Kader', '', 'HEC Montréal', "Auxiliaire d'enseignement en Technologies de l'Information ", '07 Feb 2018"']
# ['"Steffi', 'Haag', '', 'Friedrich-Alexander-Universität (FAU) Erlangen-Nürnberg', 'Juniorprofessorin für Wirtschaftsinformatik', '31-janv-18"']
# ['"Manon', 'Stévenne', '', 'Amazon', 'Operations Analyst Intern', '09-janv-18"']
# ['"Verena', 'Gruber', '', 'HEC Montréal', 'Associate Professor', '30 Dec 2017"']
# ['"Jinglu', 'Jiang\x90', '', 'HEC Montréal', 'PHD Candidate', '12 Dec 2017"']
# ['"William', 'Labonté', '', 'Sonepar Canada', 'Scientifique des données', '08 Dec 2017"']
# ['"Fiona', 'Fung, CPA, CMA', '', 'Nakisa', 'Technical Accountant', '19-oct-17"']
# ['"Kim Chi', 'Huynh', '', 'Kronos Incorporated - AD OPT', 'Software Support Manager', '17-oct-17"']
# ['"Natalia', 'Aguilar Delgado', '', 'HEC Montréal', 'Assistant Professor', '05-oct-17"']
# ['"Claude', 'Laurin, PhD, FCMA, FCPA', '', 'HEC Montreal', 'Directeur des affaires professorales', '04-oct-17"']
# ['"Johnathon', 'Cziffra', '', 'HEC Montréal', 'Assistant Professor', '04-oct-17"']
# ['"Patrick', 'Fontaine', '', 'La Céleste Levure', 'Comptable et responsable des ressources humaines', '02-oct-17"']
# ['"Laila', 'Dahabiyeh', '', 'University of Jordan', 'Assistant Dean for Development and Quality Assurance Affairs', '23-sept-17"']
# ['"Patricia', 'Prato-Casado', '', 'Auxly', 'Regulatory Affairs - International Markets ', '30-juil-17"']
# ['"Rajiv', 'Kohli', '', 'The College of William & Mary', 'John N. Dalton Memorial Professor of Business', '16-juil-17"']
# ['"Gwen', 'LELU', '', 'C&G Relocalisation', 'Relocation counsellor and residential real estate broker', '15-juil-17"']
# ['"Chi Yung', 'Chieng', '', 'Santander UK', 'Technology & Operations Graduate', '15-juil-17"']
# ['"Marta', 'Plaza', '', 'HP', 'CS EMEA Print Advanced Technical Support Manager', '05-juil-17"']
# ['"Mariel', 'Cremlis', '', 'Zone', 'Digital Transformation ', '21-juin-17"']
# ['"Mohanish', 'Vaidya', '', 'Wishberry Films ', 'Manager Investor Relations', '21-juin-17"']
# ['"Andrew', 'Cranwell', '', 'Barclays', 'API Director', '19-juin-17"']
# ['"Juanita', 'Collins', '', 'Air BP', 'Marketing and  Business Development Manager North, Central  & Western Europe', '19-juin-17"']
# ['"Becks', 'Grainger', '', 'Baringa Partners', 'Senior Manager', '18-juin-17"']
# ['"Amitava', 'Mitra', '', 'SAP', 'Senior Business Process Consultant', '16-juin-17"']
# ['"James', 'Oliver MBA PMP', '', 'Jaguar Land Rover', 'Project Manager - Commercial', '16-juin-17"']
# ['"James', 'Soo', '', 'Orange Business Services', 'SDx APAC Business Development', '16-juin-17"']
# ['"Simon', 'Quarshie, MBA', '', 'Swiss Post Solutions UK', 'National Account Manager', '14-juin-17"']
# ['"Mohamed T.', 'Fettah', '', 'VMware', 'Associate Consultant', '14-juin-17"']
# ['"Adam', 'Griffiths', '', 'Elbit Systems UK Ltd', 'Programmes & Engineering Director', '12-juin-17"']
# ['"Dr Sunil', 'Mithas', '', 'University of South Florida Muma College of Business', 'World Class Scholar and Professor', '05-juin-17"']
# ['"', '', '', '', '', '05-juin-17"']
# ['"Shamel', 'Addas', '', "Smith School of Business at Queen's University", 'Assistant Professor & Distinguished Faculty Fellow of Management Information Systems', '26 May 2017"']
# ['"Justin', 'McArthur', '', 'University of Warwick', 'Operations Director, WBS Undergraduate Programme', '15 May 2017"']
# ['"Gongtai', 'Wang', '', 'UQ Business School', 'Postdoctoral Researcher', '11 May 2017"']
# ['"William', 'McNally', '', 'Wilfrid Laurier University', 'Associate Professor', '08 May 2017"']
# ['"Lali', 'Torma', '', 'self-emplyed', 'Artist', '23 Apr 2017"']
# ['"AnaÃ¯s', 'Jauer', '', 'ChewyMoon', 'Digital Marketing Analytics Intern', '06 Apr 2017"']
# ['"Stefan', 'Tams', '', 'HEC Montréal', 'Assistant Professor of Information Systems', '05 Apr 2017"']
# ['"Kevin', 'Carillo', '', 'Toulouse Business School (TBS)', 'Assistant Professor in Information Systems', '30-mars-17"']
# ['"Tamara', 'Friedrich', '', 'University of Warwick', 'Associate Professor of Entrepreneurship and Innovation', '27-mars-17"']
# ['"Hermann', 'Juergens', '', 'BoÄŸaziçi Ãœniversitesi', 'Assistant Professor of Strategic Management', '27-mars-17"']
# ['"Janice', 'Ong', '', 'McGill University', 'Financial Data Analyst', '27-mars-17"']
# ['"Pierre-Majorique', 'Léger', '', 'HEC Montréal', 'NSERC-Prompt Industrial Research Chair in User Experience and Full Professor of IT', '22-mars-17"']
# ['"Vikki', 'Abusidualghoul', '', 'Warwick Business School â€“ University of Warwick', 'Associate Professor (Operations)', '21-mars-17"']
# ['"', '', '', '', '', '20-mars-17"']
# ['"Dave', 'Snowden', '', 'Cognitive Edge', 'Founder and Chief Scientific Officer', '20-mars-17"']
# ['"Sanja', 'Tumbas', '', 'IESE Business School', 'Assistant Professor of Information Systems ', '20-mars-17"']
# ['"Julia', 'Kotlarsky', '', 'The University of Auckland', 'Professor, Information Systems and Operations Management Department', '20-mars-17"']
# ['"Suprateek', 'Sarker', '', 'McIntire School of Commerce', 'Rolls-Royce Commonwealth Commerce Professor (IT)', '20-mars-17"']
# ['"Dr. Alexander', 'Eck', '', 'Volkswagen AG', 'International Rollout Digital Platform', '20-mars-17"']
# ['"Camille', 'Grange', '', 'University of British Columbia', 'Doctoral Student', '19-mars-17"']
# ['"Irina', 'David', '', 'IBM', 'Technology Consultant', '19-mars-17"']
# ['"Dan', 'Chohan', '', 'eBECS', 'Microsoft Dynamics Consultant', '27 Feb 2017"']
# ['"Tuure', 'Tuunanen', '', 'University of Jyväskylä', 'Professor', '14 Feb 2017"']
# ['"Channelle', 'Hylton', '', 'Vodafone', 'IOT Scrum Master ', '14 Feb 2017"']
# ['"Robert', 'Dyson', '', 'University of Warwick', 'Emeritus Professor', '20-janv-17"']
# ['"Charlie', 'Keegan', '', 'Fujitsu Global', 'Cyber Security Analyst', '10-janv-17"']
# ['"Anette', 'Moolenaar', '', 'Gaiaverse', 'Freelance writer, translator & revisor', '06-janv-17"']
# ['"Ruxanda', 'Berghi', '', 'ING Belgium', 'Senior Associate Finance Control', '20 Dec 2016"']
# ['"Marius', 'Popescu', '', 'Fresenius Kabi', 'Product manager oncology', '08-nov-16"']
# ['"Emilie', 'Fortin-Lefebvre', '', 'UQAM | Université du Québec à Montréal', 'Professeure', '09 Aug 2016"']
# ['"Dmitry', 'Dayneko, MBA', '', 'Accenture', 'Speciality Lead', '04 Aug 2016"']
# ['"Katerina', 'Antonopoulou', '', 'University of Sussex', 'Lecturer (Assistant Professor) in Information Systems', '26-juil-16"']
# ['"Linda', 'Timofan', '', '', '', '05-juil-16"']
# ['"Radka', 'Kadnarova, PhD', '', 'Facebook (Contract)', 'UX Researcher', '29-juin-16"']
# ['"', '', '', '', '', '27-juin-16"']
# ['"Pamela', 'Pinski', '', 'Warwick Business School', 'Corporate Relations Manager', '15-juin-16"']
# ['"Akan', 'Ukwak', '', 'Multiple', 'Project Manager', '14-juin-16"']
# ['"James', 'Nethercott', '', 'Regulatory Finance Solutions', 'Group Head Marketing', '13-juin-16"']
# ['"Alessandro', 'Santini', '', 'Accenture', 'Principal Director, Intelligent Engineering Services', '12-juin-16"']
# ['"Jonathan', 'Taylor', '', 'x-tention Informationstechnologie GmbH', 'Managing Director (UK&I)', '12-juin-16"']
# ['"Jade Wendy', 'Brooks', '', 'Loughborough University School of Business and Economics', 'Lecturer of Innovation and International Management', '12-juin-16"']
# ['"Harjit', 'Dewar ', '', 'Shell', 'Operational Risk and Security Lead', '11-juin-16"']
# ['"Marina Zouni', 'Hallworth CEng MBA', '', 'The Lighthouse Furniture Project', 'Trustee and Director', '11-juin-16"']
# ['"Denise', 'Mullen', '', 'HealthShare NSW', 'Strategic Procurement and Partnering Consultant', '11-juin-16"']
# ['"Isa', 'Truchet', '', 'Accenture', 'Technology Consultant Manager', '11-juin-16"']
# ['"Isaac', 'Vaghefi', '', 'Pace University', 'Assistant Professor of Information Systems', '20-mars-16"']
# ['"Alex', 'Serban', '', 'Road Grand Tours', 'CEO, CTO', '20-mars-16"']
# ['"Stuart', 'Towns', '', 'KPMG UK', 'Business Intelligence Consultant', '12-mars-16"']
# ['"Jana', 'MandovÃ¡', '', 'Darktrace', 'Cyber Technology Specialist', '05-mars-16"']
# ['"Shammi', 'Shah', '', 'GiveMeTap', 'Customer Engagment Lead', '07 Feb 2016"']
# ['"Alex', 'Millar', '', 'National Grid', 'Graduate Buyer ', '23-janv-16"']
# ['"Alain', 'Fortier', '', 'Revenu Québec', 'Advisor Enterprise Architecture', '04-janv-16"']
# ['"Victoria', 'Rudenko', '', 'Self-employed', 'Digital Marketing Strategist', '26-nov-15"']
# ['"Philipp', 'Hukal', '', 'Copenhagen Business School', 'Assistant Professor', '26-oct-15"']
# ['"Dr Bo', 'Kelestyn FHEA', '', 'University of Warwick', 'Student Surveys Analyst', '17-oct-15"']
# ['"Robin', 'Som', '', 'Lewisham and Greenwich NHS Trust', 'Surgical Registrar', '30 Aug 2015"']
# ['"Mostafa', 'Mesgari', '', '', '', '02 Aug 2015"']
# ['"Marc Christopher', 'Held', '', 'GE', 'Commercial Proposal Director', '18-juil-15"']
# ['"Dovile', 'Sniokaite', '', 'Swedbank', 'Accounting & Financial Reporting (IFRS) Expert, Group Finance', '13-juil-15"']
# ['"Christina', 'Murias', '', 'Herxide', 'Land Acquisition Manager', '19-juin-15"']
# ['"Shaurya', 'Mehta', '', 'Metcon India Realty & Infrastruture Pvt. Ltd.', 'Director', '17-juin-15"']
# ['"David', 'McCafferty', '', 'Kabanski Associates Ltd', 'Managing Director', '17-juin-15"']
# ['"Joshua', 'Tedam', '', 'Cognizant', 'Enterprise Architect - Consulting', '17-juin-15"']
# ['"Dr Nicola', 'Burgess', '', 'Warwick Business School', 'Associate Professor of Operations Management', '30 Apr 2015"']
# ['"Mario', 'Ramotar, PhD', '', 'CWT', 'Senior UX Researcher', '07 Apr 2015"']
# ['"Ana', 'Ortiz de Guinea Lopez de Arana', '', 'Deusto Business School', 'Associate Professor - Director of the Digital Environments Management Program', '01 Apr 2015"']
# ['"Natalia', 'Levina', '', 'New York University', 'Full Professor, Toyota Motors Corp. Term Chair', '31-mars-15"']
# ['"Sanjana', 'Ramamurthy', '', 'EY', 'Manager', '31-mars-15"']
# ['"Mathew', 'Tuvesson', '', 'Checkout.com', 'Senior Product Manager', '29-mars-15"']
# ['"Andrew', 'Thomas', '', 'Yopa Property', 'Front-end developer', '10-mars-15"']
# ['"Leanne', 'Allen', '', 'KPMG UK', 'Director', '02-mars-15"']
# ['"Nick', 'Blewden', '', "Lloyd's", 'Head of Data Product Development', '25 Feb 2015"']
# ['"Xing', 'Yu', '', 'PwC SDC Shanghai', 'Manager', '18 Feb 2015"']
# ['"Heidi', 'Emami', '', 'McGill University', 'Associate Registrar, Academic Records and Examinations', '16-janv-15"']
# ['"Mara', 'Ivan', '', 'Apple', 'Manager, Data Systems', '09-janv-15"']
# ['"Andra', 'Serban', '', 'Virginia Commonwealth University - School of Business', 'Assistant Professor', '05 Dec 2014"']
# ['"Dr. Hari Suman', 'Naik', '', 'adidas', 'Senior Project Manager', '24-nov-14"']
# ['"Laura', 'Winer', '', 'McGill University', 'Director, Teaching and Learning Services', '18-nov-14"']
# ['"Juliane', 'Reinecke', '', "King's Business School", 'Professor of International Management & Sustainability', '05-nov-14"']
# ['"Alexie', 'Labouze-Nasica, Ph.D.', '', 'École des sciences de la gestion (ESG UQAM)', 'Professor of Strategic Management', '27-oct-14"']
# ['"Paolo', 'Quattrone', '', 'Harbour of Cultures', 'Vice President', '22-oct-14"']
# ['"Minwoo', 'Lee', '', 'University of Houston, Conrad N. Hilton College of Hotel and Restaurant Management', 'Assistant Professor', '02-oct-14"']
# ['"Mohammad', 'Nikoofal', '', 'Ryerson University, Ted Rogers School of Management', 'Assistant Professor of Operations and Supply Chain Management', '11-sept-14"']
# ['"Gregory', 'Vial', '', 'HEC Montréal', 'Assistant Professor of Information Technology', '09-sept-14"']
# ['"Elena', 'Patulli', '', 'McGill University', 'Senior Functional Business Analyst', '21 Aug 2014"']
# ['"Adam', 'Finkelstein', '', 'McGill University', 'Associate Director, Learning Environments, Teaching and Learning Services', '18 Aug 2014"']
# ['"Bo', 'Yu', '', 'Rowe School of Business, Dalhousie University', 'Assistant Professor', '12 Aug 2014"']
# ['"Mathieu', 'Templier', '', 'Université Laval', 'Associate Professor', '09 Aug 2014"']
# ['"Mariachiara', 'Restuccia', '', 'University of Sussex', 'Lecturer in Marketing', '24-juil-14"']
# ['"Alina', 'Dulipovici', '', 'HEC Montréal', 'Associate Professor', '22-juil-14"']
# ['"Frank', 'Babics', '', 'McGill University', 'Manager Graduate Admissions', '21-juil-14"']
# ['"Aleksi', 'Aaltonen', '', 'Temple University', 'Assistant Professor', '10-juil-14"']
# ['"Youngjin', 'Yoo', '', 'Case Western Reserve University - Weatherhead School of Management', 'Elizabeth M. and William C. Treuhaft Professor in Entrepreneurship', '31 May 2014"']
# ['"Hoda', 'Nasseri', '', 'Deloitte Consulting', 'Cyber Security Reporting and Analytics Project Manager', '12 May 2014"']
# ['"Hanieh', 'Moshki', '', 'PwC Canada', 'Manager, Cybersecurity and Privacy', '20 Apr 2014"']
# ['"Onook', 'Oh', '', 'University of Colorado Denver Business School', 'Assistant Professor', '10 Apr 2014"']
# ['"Joe', 'Nandhakumar', '', 'Warwick Business School', 'Professor of Information Systems', '02 Apr 2014"']
# ['"', '', '', '', '', '06-mars-14"']
# ['"Victoria', 'Grandury', '', 'Deloitte Canada', 'Manager - Cyber Risk', '13 Feb 2014"']
# ['"Elodie', 'Cheong Youne', '', 'ExxonMobil', 'Project Track Lead', '07 Feb 2014"']
# ['"IsraÃ«l', 'Fortin, Ph.D.', '', 'Indian Institute of Management Bangalore', 'Assistant Professor', '01 Feb 2014"']
# ['"Claire', 'Ingram Bogusz', '', 'University of Gothenburg', 'Postdoctoral Researcher', '02-janv-14"']
# ['"Anna', 'Karpovsky', '', 'Boston College Carroll School of Management', 'Assistant Professor of Practice', '02-janv-14"']
# ['"Jan', 'Damsgaard', '', 'Copenhagen Business School', 'Professor', '02-janv-14"']
# ['"Lauren', 'Rhue', '', 'Wake Forest University School of Business', 'Assistant Professor', '28 Dec 2013"']
# ['"Sumantra', 'Sarkar', '', 'School of Management, Binghamton University', 'Assistant Professor', '23 Dec 2013"']
# ['"Lena', 'Hylving', '', 'Halmstad University', 'Associate Professor', '16 Dec 2013"']
# ['"Quang Neo', 'Bui', '', 'Rochester Institute of Technology', 'Assistant Professsor', '14 Dec 2013"']
# ['"Stella', 'Pachidi', '', 'Cambridge Judge Business School', 'University Lecturer (Assistant Professor)', '14 Dec 2013"']
# ['"Ola', 'Henfridsson', '', 'University of Miami Business School', 'Professor of Business Technology', '14 Dec 2013"']
# ['"Elena', 'Karahanna', '', 'Terry College of Business, University of Georgia', 'Distinguished Research Professor and L. Edmund Rast Professor of Business', '13 Dec 2013"']
# ['"Anne-Marie', 'Croteau, PhD, CDir', '', 'Hydro-Québec', 'Board Member', '02 Dec 2013"']
# ['"Sergiu', 'Popescu', '', '', '', '04-nov-13"']
# ['"Gerald', 'Kane', '', 'Boston College - Wallace E. Carroll Graduate School of Management', 'Professor', '29-oct-13"']
# ['"Ron', 'Leisti', '', 'NetSuite', 'Principal Software Developer', '21-oct-13"']
# ['"Denise', 'Nahas', '', 'LightSpeed Retail', 'VP,  Customer Support', '18-oct-13"']
# ['"Kyung', 'Lee', '', 'Dalhousie University', 'Associate Professor', '14-sept-13"']
# ['"Saeed', 'Akhlaghpour', '', 'UQ Business School', 'Senior Lecturer', '09-sept-13"']
# ['"Rima', 'El-Khatib, PhD', '', 'Prince Mohammad Bin Fahd University', 'Assistant Professor', '07-sept-13"']
# ['"Julien', 'Meyer', '', 'Ryerson University', 'Assistant Professor', '05-sept-13"']
# ['"Benoit', 'Aubert', '', 'Dalhousie University', 'Director - Rowe School of Business', '22 Aug 2013"']
# ['"Forough', 'Karimi-Alaghehband', '', 'HEC Montréal', 'Instructional Designer', '12-juil-13"']
# ['"Shelagh', 'Pepper', '', 'Wilfrid Laurier University', 'Associate Registrar, Registrarial Services and Systems', '06-juil-13"']
# ['"Nermein', 'Gamal', '', 'McGill University', 'Assistant Registrar, Systems, Project and Change Management', '22-juin-13"']
# ['"Simon', 'Fulleringer', '', 'McGill University', 'Asset & Configuration Management Process Manager', '18-juin-13"']
# ['"PetruÈ›a', 'Popescu', '', 'Homeopetra SRL', 'Medic specialist MF', '18-juin-13"']
# ['"Chahin', 'Kordlouie DMD', '', 'Melville Dental Group', 'Dentist', '11-juin-13"']
# ['"Lorne', 'Wald', '', 'McGill University', 'Data Security Analyst', '11-juin-13"']
# ['"Mahmood', 'Shafeie Zargar', '', 'Vrije Universiteit Amsterdam / VU', 'Assistant Professor', '23 Apr 2013"']
# ['"Ghazaleh', 'Aghili', '', 'McGill University - Desautels Faculty of Management', 'Lecturer', '21 Apr 2013"']
# ['"Paul', 'Leonardi', '', 'UC Santa Barbara', 'Duca Family Professor of Technology Management', '13 Apr 2013"']
# ['"Brian', 'Pentland', '', 'Michigan State University', 'Professor', '13 Apr 2013"']
# ['"Kunsoo', 'Han', '', 'Desautels Faculty of Management, McGill University', 'Associate Professor', '03 Apr 2013"']
# ['"', '', '', '', '', '25 Feb 2013"']
# ['"Colin', 'Abbott', '', 'McGill University', 'IT Security Architect', '14 Feb 2013"']
# ['"Diego', 'Mastroianni, PhD', '', "Moody's Analytics", 'Director of Implementation Services', '06 Feb 2013"']
# ['"John', 'Kim', '', 'RBC Capital Markets', 'Data Strategist', '25-janv-13"']
# ['"', '', '', '', '', '24-janv-13"']
# ['"Andrew', 'Dias', '', 'McGill University', 'Technical Leader, Application Development', '23-janv-13"']
# ['"Louis-Clément', 'Schiltz ðŸ¤–ðŸš€', '', 'WEBOTIT', 'President', '17-janv-13"']
# ['"James', 'Denford', '', 'Royal Military College of Canada/Collège militaire royal du Canada', 'Dean, Faculty of Social Sciences and Humanities', '27 Dec 2012"']
# ['"', '', '', '', '', '24 Dec 2012"']
# ['"David J.', 'Stenason', '', 'Rempart Asset Management', 'Managing Director', '22-nov-12"']
# ['"José Carlos', 'Marques', '', 'Telfer School of Management at the University of Ottawa', 'Assistant Professor - Strategy, Corporate Responsibility and Sustainability', '21-nov-12"']
# ['"Daniel', 'Trotto', '', 'McGill University', 'BI Developer', '21-nov-12"']
# ['"Manon G.', 'Guillemette', '', 'Technopolys', 'Ambassador', '22-oct-12"']
# ['"Andrew', 'Burton-Jones', '', 'UQ Business School, The University of Queensland', 'Professor', '21-oct-12"']
# ['"Manju', 'Ahuja', '', "University of Louisville's College of Business", 'Professor and University Scholar', '19-oct-12"']
# ['"Brian', 'Arsenault', '', 'McGill University', 'Manager Enterprise Desktop Solutions', '01-oct-12"']
# ['"Rita M.', 'Benitez', '', 'UNFCCC', 'Associate Knowledge Management Officer', '05-sept-12"']
# ['"Deborah', 'Compeau', '', 'Washington State University - Carson College of Business', 'Senior Associate Dean for Faculty Affairs and Research', '25 Aug 2012"']
# ['"Thibaut', 'Coulon', '', 'École des sciences de la gestion (ESG UQAM)', 'Assistant Professor', '23 Aug 2012"']
# ['"Bill', 'Kennedy', '', 'US Overseas Private Investment Corporation (OPIC)', 'Director, Office of Accountability', '23 Aug 2012"']
# ['"Denisa', 'Voicu', '', 'Hager Group', 'LEAN SENIOR MANAGER (Member of Management Team)', '19-juil-12"']
# ['"Mohammad', 'Moeini', '', 'University of Sussex', 'Lecturer (Assistant Professor) in Information Systems', '17-juil-12"']
# ['"Mustapha', 'Cheikh-Ammar', '', 'Ivey Business School', 'Assistant Professor', '28-juin-12"']
# ['"Catherine', 'Marchand, Ph.D.', '', 'Centre for Health Services Studies', 'Senior Trial Manager for RISKIT-CJS', '15-juin-12"']
# ['"Josianne', 'Marsan', '', 'Université Laval', 'Full Professor', '15-juin-12"']
# ['"Eve', 'Lamargot', '', 'Lazaridis School of Business & Economics at Wilfrid Laurier University', 'Professeure adjointe (instructrice) en contrôle de gestion', '13-juin-12"']
# ['"Genevieve', 'Bassellier', '', 'McGill University', 'Associate Professor', '07-juin-12"']
# ['"Gruia', 'Pitigoi-Aron', '', 'The Trade Desk', 'VP, Product', '15 May 2012"']
# ['"Nolywé', 'Delannon', '', 'Université Laval', 'Assistant Professor', '22 Apr 2012"']
# ['"Jui', 'Ramaprasad', '', 'McGill University - Desautels Faculty of Management', 'Associate Professor', '22 Apr 2012"']
# ['"Joleen', 'Khoury', '', 'Caisse de dépôt et placement du Québec (CDPQ)', 'Manager - Security Architecture, Analytics & Controls', '12 Apr 2012"']
# ['"Elisa', 'Gagnon, Ph.D', '', "Williams School of Business at Bishop's University", 'Assistant Professor', '03 Apr 2012"']
# ['"Kindness', 'Keong, MBA, PMP', '', 'Jardine Matheson', 'Manager, Innovation', '02-mars-12"']
# ['"Elan', 'Weinstock', '', 'Amazon', 'Software Development Engineer', '10 Feb 2012"']
# ['"Azadeh', 'Savoli', '', 'IÉSEG School of Management', 'Assistant Professor', '26-janv-12"']
# ['"Carlos A.', 'Rodriguez', '', 'INCAE Business School', 'Assistant Professor of Strategy and Organizations', '15 Dec 2011"']
# ['"Dan', 'Pilat', '', 'The Decision Lab', 'Co-Founder, Managing Director', '15 Dec 2011"']
# ['"Marlous', 'Agterberg', '', 'KIN Center for Digital Innovation', 'Research and Valorisation Manager', '15 Dec 2011"']
# ['"Isla', 'Milne', '', 'McGill University', 'PhD Candidate, Strategy and Organization, Desautels Faculty of Management', '15 Dec 2011"']
# ['"Nada O.', 'Basir, PhD', '', 'University of Waterloo - Conrad Business, Entrepreneurship and Technology Centre', 'Assistant Professor - Strategic Management', '15 Dec 2011"']
# ['"Soha', 'Hawili', '', 'Concordia University', 'Academic Advisor', '15 Dec 2011"']
# ['"Jean-Francois', 'Belisle', '', 'Life House', 'Senior Director - Data Science & Revenue Management', '01 Dec 2011"']
# ['"Ali', 'Javed, PMP', '', 'Facebook', 'Business Operations Analyst - Infrastructure Business Operations', '30-nov-11"']
# ['"Yasser', 'Rahrovani', '', 'Ivey School of Business - The University of Western Ontario', 'Assistant Professor', '30-nov-11"']
# ['"Chris', 'Matthijsse', '', 'McGill University', 'Senior Analyst', '16-nov-11"']
# ['"Tia (Teodora)', 'Lazar', '', 'Endava', 'Lead Project Management Officer', '15-nov-11"']
# ['"Régis', 'Barondeau', '', 'École des sciences de la gestion (ESG UQAM)', 'Professor', '22 Feb 2011"']
# ['"Eric', 'Beaulieu', '', 'Solumax Consulting Services', 'Owner', '26-janv-11"']
# ['"Alain', 'Pinsonneault', '', 'McGill University', 'Professor', '12-oct-10"']
# ['"Russell', 'Seidle', '', 'Suffolk University', 'Assistant Professor', '07-oct-10"']
# ['"Kristin', 'Korim', '', 'Parliament of Canada', 'Functional Lead, Human Resources Management System Renewal and Change Management', '02-sept-10"']
# ['"Cristina', 'Tanasescu', '', 'VMware', 'Manager, Partner Organization, Mediterranean & Eastern Europe', '06 Aug 2010"']
# ['"Daniela', 'Thions', '', 'McKinsey & Company', 'Engagement Manager', '05 Aug 2010"']
# ['"Venu', 'Katikaneni', '', 'McGill', 'Programmer', '30-janv-10"']
# ['"Suzanne', 'Rivard', '', 'HEC Montreal', 'Professeur', '12 Dec 2009"']
# ['"Frederick', 'Le Page', '', 'Bell Business Markets', 'Project Executive', '27-nov-09"']
# ['"Animesh', 'Animesh', '', 'McGill University', 'Associate Professor', '08-oct-09"']
# ['"Hani', 'Safadi', '', 'University of Georgia - Terry College of Business', 'Assistant Professor', '17-sept-09"']
# ['"Stephan', 'Lukac', '', 'Best Buy Canada', 'Senior Marketing Manager', '31 Aug 2009"']
# ['"Mike', 'Deutsch', '', 'Kids Code Jeunesse', 'Director of Educational Development', '31 Aug 2009"']
# ['"Thierry', 'Mayrand', '', 'McGill University', 'Solutions Architect', '31 Aug 2009"']
# ['"Marc', 'Huffstickler', '', 'Texas A&M University', 'Software Application Developer', '02-juil-09"']
# ['"Sue', 'Reali', '', 'Bristol-Myers Squibb', 'Director, Information Systems', '13-juin-09"']
# ['"Salaheddin', 'Baki', '', 'Solutions Metrix - Certified CRM Partner (Microsoft, Oracle, Salesforce & SugarCRM)', 'Director Of Development', '11-juin-09"']
# ['"Jean Paul', 'Merymo', '', 'TD', 'AVP', '18 May 2008"']
# ['"Mario', 'Rossi', '', 'CAE', 'Manager, Market Pricing and Strategy (Product Management)', '16 May 2008"']
# ['"Gustavo', 'Mothe, MBA', '', 'IMC - Instituto Modelo de Cardiologìa Privado ', 'Project Leader, Process Quality and Continuous Improvement Management ', '25 Apr 2008"']
# ['"Christian', 'Caron', '', 'Google', 'Staff Software Engineer and Manager', '25 Apr 2008"']
# ['"Srdjan', 'Jovanovic', '', 'Pfizer', 'Manager Operational Excellence', '26-oct-07"']
# ['"Melanie', 'Wilson', '', 'Workplace Safety & Prevention Services', 'Organizational Development and Performance Specialist', '01-juil-07"']
# ['"Alexandra', 'Kapelos-Peters, PMP, CSM, MBA candidate', '', 'Stratenym', 'Co-Founder and Vice President, Chief Operating Officer', '08-mars-07"']
# ['"Thuy (Twee) ', 'Nguyen', '', 'North', 'Supplier Development Engineer', '07-mars-07"']
# ['"Alex', 'Mendelev', '', 'DoubleJump Games', 'CEO', '07-mars-07"']
# ['"Florin', 'Negoita', '', 'OntarioMD', 'Sr. Project Manager', '07-mars-07"']
# ['"Albina', 'Shapiro', '', 'SAP Labs', 'Product Owner', '17 Feb 2007"']
# ['"Sydney', 'Vasseur', '', 'Gemini Data Inc.', 'Business Development Representative EMEA', '24-nov-16"']
# ['"Brian', 'Lack', '', 'Simply Voting Inc.', 'President', '15 Dec 2011"']
# ['"Nolwen', 'Mahé', '', 'Alsago Inc.', 'Consultant, Agile governance', '02 Dec 2011"']
# ['"Marlene', 'Newton', '', 'Informatique Newton Inc.', 'Senior Project Manager', '11-juin-09"']

# %% [markdown]
# Bien que chaque liste contienne exactement 6 éléments, on observe que le premier élément contient un guillement superflu au début (par exemple, `'"Mélanie'`) et que le dernier élément contient un guillement superflu à la fin (par exemple, `'17-sept-18"'`). On voudra donc retirer ces éléments. Pour ce faire, nous utiliserons des *slices* dans les valeurs textuelles:
#
# - La *slice* `[1:]` pour retirer le premier guillement, préservant tous les caractères partant de l'index 1 (le 2e caractère) jusqu'à la fin du texte.
# - La *slice* `[:-1]` pour retirer le deuxième guillement, préservant tous les caractères du début du texte au caractère à l'index -1 (l'avant-dernier index).
#
# En appliquant ces transformations, on constate que les données sont dans le format désiré.

# %%
# On découpe chaque ligne, sauf la première qui se trouve à l'index 0
for i in range(1, len(connexions)):
    
    # On enlève les caractères superflus et on découpe autour de la séquence de caractères ","
    data = connexions[i].strip().split('","')
    
    # On modifie le premier élément en retirant le premier caractère
    # data : liste contenant les six détails d’un contact
    # data[0] : isole le premier détail d’un contact (par ex., "Mélanie)
    # [1: ] : coupe ce premier détail et génère une tranche à partir de son 2ieme caractère 
                # jusqu’à la fin (par ex., Mélanie)
    # data[0] = data[0][1:] : j’assigne la chaine de caractères ainsi traité (par ex., Mélanie)
                # à mon premier détail d’un contact, « overwriting » son ancienne valeur qui était "Mélanie
    data[0] = data[0][1:]
    
    # On modifie le dernier élément en retirant le dernier caractère
    # data[-1] : isole le dernier détail d’un contact (par ex., 17-sept-18")
    # [ :-1] : coupe ce dernier détail et génère une tranche à partir de son 1er caractère 
                # jusqu’à son avant-dernier caractère (par ex., 17-sept-18)
    # data[-1] = data[-1][ :-1] : j’assigne la chaine de caractères ainsi traité (par ex., 17-sept-18)
                # à mon dernier détail d’un contact, « overwriting » son ancienne valeur qui était 17-sept-18"    
    data[-1] = data[-1][:-1]
    
    # On affiche le résultat
    print(data)
# Out:
# ['Mélanie', 'Dénommée', '', 'Essilor Canada', "Chef Partenariat d'affaires RH/HRBP Manager", '17-sept-18']
# ['Justine', 'Authier, MSc', '', 'HEC Montréal', 'Lecturer | Database Management Course', '28-mars-18']
# ['Elodie', 'Champoux', '', 'CBC', "Première Analyste Intelligence d'Affaires | Senior Business Intelligence Analyst ", '27-mars-18']
# ['Jean', 'Talbot', '', 'HEC Montreal', 'Professeur titulaire / Full Professor', '19-juin-17']
# ['Karsten', 'Herr', '', 'Darling Ingredients Germany Holding GmbH', 'Technical Director Germany/CTO', '15-juin-16']
# ['Mina', 'Rohani', '', 'Key Lime Interactive', 'UX Researcher @ Google + Senior Quantitative Researcher @ KLI', '07-janv-15']
# ['Markos', 'Zachariadis', '', 'Ivey Business School at Western University', 'Visiting Professor/Faculty in Financial Technologies (FinTech)', '09 May 2014']
# ['Anne', 'Chartier', '', 'Université Laval', 'Associate professor / Professeure agrégée', '30-janv-14']
# ['Jean-François', 'Brodeur', '', 'Collège de Bois-de-Boulogne', "Enseignant département d'informatique / Teacher", '16-oct-13']
# ['Eric', 'Segal, MD, MSc, BCom, BSc', '', "CIUSSS de l'Estrie - CHUS", 'Resident Physician / Médecin Résident', '26 May 2012']
# ['Razvan', 'Radulian', '', 'Why-What-How Consulting, LLC', 'Independent Consultant/Owner', '06 Apr 2012']
# ['Augustin', 'Bilolo', '', 'Banque Nationale', 'Senior Analyst / Developer IBM WebSphere Portal', '25 Aug 2010']
# ['Ben', 'Breiner', '', 'Amgen', 'Executive Biopharmaceutical Representative - Rheumatology/Dermatology', '25 Apr 2008']
# ['Nita', 'Hayre', '', 'Warwick Business School', 'Group Coordinator', '02-juil-19']
# ['Don', 'MacLean', '', 'HEC Montréal', 'Doctoral Candidate', '12 May 2019']
# ['Karim', 'Emond', '', 'National Research Council Canada / Conseil national de recherches Canada', 'Data Scientist', '09 Apr 2019']
# ['Charlotte', 'Blanche', '', 'HEC Montréal', 'Chargée de cours - Management Interculturel', '04 Apr 2019']
# ['Paul', 'Ranson (MBA)', '', 'University of Wales Trinity Saint David', 'Visiting Lecturer', '28 Feb 2019']
# ['Tuba', 'Tuncel', '', 'Toulouse School of Economics', 'Phd Candidate', '04 Feb 2019']
# ['Haris', 'Krijestorac', '', 'ProdamSam.com', 'Web Strategist, Partner', '28-janv-19']
# ['John', 'Wade', '', 'Creative Destruction Lab - Montreal', 'Venture Recruiter', '01-nov-18']
# ['Audrey', 'Leduc', '', 'Breathe Life', 'Projet supervisé de maîtrise - science des données', '31-oct-18']
# ['Asif', 'Ansari, MBA', '', 'TELUS Business', 'Product Manager', '30-oct-18']
# ['Peter', 'Bachour', '', 'IBM Client Innovation Center Montreal', 'Business Transformation Consultant: Talent & Mobilisation', '24-oct-18']
# ['José A.', 'Cofré', '', 'Olam', 'Head of Legal, Europe', '21-oct-18']
# ['Rachel', 'Cook', '', 'Lumesse', 'Head of Business Transformation', '04-sept-18']
# ['Gilbert', 'Babin', '', 'HEC Montréal', 'Director, Department of Information Technologies', '20 Aug 2018']
# ['Ralph', 'Smyth', '', 'Highways England', 'Member of Strategic Design Panel', '14 Aug 2018']
# ['Asha', 'Ginda', '', 'University of Warwick - Warwick Business School', 'Deputy Programmes Manager', '30-juil-18']
# ['Leen', 'Issa', '', 'Microsoft', 'MBA Consultancy Project', '29-juin-18']
# ['Ryad', 'Titah', '', 'EM Lyon', 'Associate Professor', '27-juin-18']
# ['Louise', 'Welch MBA', '', 'PlayStation Europe', 'Director of Supply Chain Planning', '24-juin-18']
# ['James', 'Barber MBA', '', 'VALUE RETAIL MANAGEMENT LIMITED', 'Risk and Compliance Director', '24-juin-18']
# ['Olena', 'Bezkokotova', '', 'Transport for London', 'Head of Customer Operations', '08-juin-18']
# ['Mehdi', 'Lahlou', '', 'Mehdi Lahlou', 'Formateur et consultant en TI', '17 May 2018']
# ['Alice', 'Lake', '', 'Atos', 'Incoming Graduate Cyber Security Engineer', '11 May 2018']
# ['Lamiel', 'Brasseur', '', 'HEC Montréal', "Directrice - Direction de l'apprentissage et de l'innovation pédagogique", '10 May 2018']
# ['Mary-Sarah', 'Gagnon, MBA', '', 'Ubisoft Montréal', 'Marketing Data Analyst, E-Commerce', '07 May 2018']
# ['Marine', 'Avedissian', '', 'Banque Nationale', 'Stagiaire en analytique, AI & Marketing', '05 May 2018']
# ['Robert Wayne', 'Gregory', '', 'University of Virginia', 'Associate Professor', '03 May 2018']
# ['Joé', 'Martineau', '', 'HEC Montréal', 'Assistant Professor', '13 Apr 2018']
# ['Me Nancy', "O'Connor", '', "O'Connor Notaire et conseiller juridique", 'Notaire, conseillère juridique et médiatrice engagée', '04 Apr 2018']
# ['Hassen', 'Bouacida', '', 'Desjardins', 'Conseiller Principal - Personnalisation des cartes', '16-mars-18']
# ['Daphne', 'Coates', '', 'IBM', 'Watson IoT and Industry 4.0 Consultant', '14-mars-18']
# ['Zishu', 'Zhao', '', 'IBM iX', 'Technology Consymtant', '11-mars-18']
# ['Mayur P.', 'Joshi', '', 'HDFC Bank', 'Sub Unit Head- Retail Branch Control Unit, Corporate Office,', '09-mars-18']
# ['Sylvia', 'Santosa', '', 'International Journal of Obesity', 'Editorial Board Member', '20 Feb 2018']
# ['Alain', 'Elkaim', '', 'HEC Montreal', 'Trading room manager', '15 Feb 2018']
# ['Sheila', 'Tran', '', 'IN-RGY (Digital transformation consulting firm)', 'Kronos Junior Consultant', '09 Feb 2018']
# ['Rakhimé', 'Abdul Kader', '', 'HEC Montréal', "Auxiliaire d'enseignement en Technologies de l'Information ", '07 Feb 2018']
# ['Steffi', 'Haag', '', 'Friedrich-Alexander-Universität (FAU) Erlangen-Nürnberg', 'Juniorprofessorin für Wirtschaftsinformatik', '31-janv-18']
# ['Manon', 'Stévenne', '', 'Amazon', 'Operations Analyst Intern', '09-janv-18']
# ['Verena', 'Gruber', '', 'HEC Montréal', 'Associate Professor', '30 Dec 2017']
# ['Jinglu', 'Jiang\x90', '', 'HEC Montréal', 'PHD Candidate', '12 Dec 2017']
# ['William', 'Labonté', '', 'Sonepar Canada', 'Scientifique des données', '08 Dec 2017']
# ['Fiona', 'Fung, CPA, CMA', '', 'Nakisa', 'Technical Accountant', '19-oct-17']
# ['Kim Chi', 'Huynh', '', 'Kronos Incorporated - AD OPT', 'Software Support Manager', '17-oct-17']
# ['Natalia', 'Aguilar Delgado', '', 'HEC Montréal', 'Assistant Professor', '05-oct-17']
# ['Claude', 'Laurin, PhD, FCMA, FCPA', '', 'HEC Montreal', 'Directeur des affaires professorales', '04-oct-17']
# ['Johnathon', 'Cziffra', '', 'HEC Montréal', 'Assistant Professor', '04-oct-17']
# ['Patrick', 'Fontaine', '', 'La Céleste Levure', 'Comptable et responsable des ressources humaines', '02-oct-17']
# ['Laila', 'Dahabiyeh', '', 'University of Jordan', 'Assistant Dean for Development and Quality Assurance Affairs', '23-sept-17']
# ['Patricia', 'Prato-Casado', '', 'Auxly', 'Regulatory Affairs - International Markets ', '30-juil-17']
# ['Rajiv', 'Kohli', '', 'The College of William & Mary', 'John N. Dalton Memorial Professor of Business', '16-juil-17']
# ['Gwen', 'LELU', '', 'C&G Relocalisation', 'Relocation counsellor and residential real estate broker', '15-juil-17']
# ['Chi Yung', 'Chieng', '', 'Santander UK', 'Technology & Operations Graduate', '15-juil-17']
# ['Marta', 'Plaza', '', 'HP', 'CS EMEA Print Advanced Technical Support Manager', '05-juil-17']
# ['Mariel', 'Cremlis', '', 'Zone', 'Digital Transformation ', '21-juin-17']
# ['Mohanish', 'Vaidya', '', 'Wishberry Films ', 'Manager Investor Relations', '21-juin-17']
# ['Andrew', 'Cranwell', '', 'Barclays', 'API Director', '19-juin-17']
# ['Juanita', 'Collins', '', 'Air BP', 'Marketing and  Business Development Manager North, Central  & Western Europe', '19-juin-17']
# ['Becks', 'Grainger', '', 'Baringa Partners', 'Senior Manager', '18-juin-17']
# ['Amitava', 'Mitra', '', 'SAP', 'Senior Business Process Consultant', '16-juin-17']
# ['James', 'Oliver MBA PMP', '', 'Jaguar Land Rover', 'Project Manager - Commercial', '16-juin-17']
# ['James', 'Soo', '', 'Orange Business Services', 'SDx APAC Business Development', '16-juin-17']
# ['Simon', 'Quarshie, MBA', '', 'Swiss Post Solutions UK', 'National Account Manager', '14-juin-17']
# ['Mohamed T.', 'Fettah', '', 'VMware', 'Associate Consultant', '14-juin-17']
# ['Adam', 'Griffiths', '', 'Elbit Systems UK Ltd', 'Programmes & Engineering Director', '12-juin-17']
# ['Dr Sunil', 'Mithas', '', 'University of South Florida Muma College of Business', 'World Class Scholar and Professor', '05-juin-17']
# ['', '', '', '', '', '05-juin-17']
# ['Shamel', 'Addas', '', "Smith School of Business at Queen's University", 'Assistant Professor & Distinguished Faculty Fellow of Management Information Systems', '26 May 2017']
# ['Justin', 'McArthur', '', 'University of Warwick', 'Operations Director, WBS Undergraduate Programme', '15 May 2017']
# ['Gongtai', 'Wang', '', 'UQ Business School', 'Postdoctoral Researcher', '11 May 2017']
# ['William', 'McNally', '', 'Wilfrid Laurier University', 'Associate Professor', '08 May 2017']
# ['Lali', 'Torma', '', 'self-emplyed', 'Artist', '23 Apr 2017']
# ['AnaÃ¯s', 'Jauer', '', 'ChewyMoon', 'Digital Marketing Analytics Intern', '06 Apr 2017']
# ['Stefan', 'Tams', '', 'HEC Montréal', 'Assistant Professor of Information Systems', '05 Apr 2017']
# ['Kevin', 'Carillo', '', 'Toulouse Business School (TBS)', 'Assistant Professor in Information Systems', '30-mars-17']
# ['Tamara', 'Friedrich', '', 'University of Warwick', 'Associate Professor of Entrepreneurship and Innovation', '27-mars-17']
# ['Hermann', 'Juergens', '', 'BoÄŸaziçi Ãœniversitesi', 'Assistant Professor of Strategic Management', '27-mars-17']
# ['Janice', 'Ong', '', 'McGill University', 'Financial Data Analyst', '27-mars-17']
# ['Pierre-Majorique', 'Léger', '', 'HEC Montréal', 'NSERC-Prompt Industrial Research Chair in User Experience and Full Professor of IT', '22-mars-17']
# ['Vikki', 'Abusidualghoul', '', 'Warwick Business School â€“ University of Warwick', 'Associate Professor (Operations)', '21-mars-17']
# ['', '', '', '', '', '20-mars-17']
# ['Dave', 'Snowden', '', 'Cognitive Edge', 'Founder and Chief Scientific Officer', '20-mars-17']
# ['Sanja', 'Tumbas', '', 'IESE Business School', 'Assistant Professor of Information Systems ', '20-mars-17']
# ['Julia', 'Kotlarsky', '', 'The University of Auckland', 'Professor, Information Systems and Operations Management Department', '20-mars-17']
# ['Suprateek', 'Sarker', '', 'McIntire School of Commerce', 'Rolls-Royce Commonwealth Commerce Professor (IT)', '20-mars-17']
# ['Dr. Alexander', 'Eck', '', 'Volkswagen AG', 'International Rollout Digital Platform', '20-mars-17']
# ['Camille', 'Grange', '', 'University of British Columbia', 'Doctoral Student', '19-mars-17']
# ['Irina', 'David', '', 'IBM', 'Technology Consultant', '19-mars-17']
# ['Dan', 'Chohan', '', 'eBECS', 'Microsoft Dynamics Consultant', '27 Feb 2017']
# ['Tuure', 'Tuunanen', '', 'University of Jyväskylä', 'Professor', '14 Feb 2017']
# ['Channelle', 'Hylton', '', 'Vodafone', 'IOT Scrum Master ', '14 Feb 2017']
# ['Robert', 'Dyson', '', 'University of Warwick', 'Emeritus Professor', '20-janv-17']
# ['Charlie', 'Keegan', '', 'Fujitsu Global', 'Cyber Security Analyst', '10-janv-17']
# ['Anette', 'Moolenaar', '', 'Gaiaverse', 'Freelance writer, translator & revisor', '06-janv-17']
# ['Ruxanda', 'Berghi', '', 'ING Belgium', 'Senior Associate Finance Control', '20 Dec 2016']
# ['Marius', 'Popescu', '', 'Fresenius Kabi', 'Product manager oncology', '08-nov-16']
# ['Emilie', 'Fortin-Lefebvre', '', 'UQAM | Université du Québec à Montréal', 'Professeure', '09 Aug 2016']
# ['Dmitry', 'Dayneko, MBA', '', 'Accenture', 'Speciality Lead', '04 Aug 2016']
# ['Katerina', 'Antonopoulou', '', 'University of Sussex', 'Lecturer (Assistant Professor) in Information Systems', '26-juil-16']
# ['Linda', 'Timofan', '', '', '', '05-juil-16']
# ['Radka', 'Kadnarova, PhD', '', 'Facebook (Contract)', 'UX Researcher', '29-juin-16']
# ['', '', '', '', '', '27-juin-16']
# ['Pamela', 'Pinski', '', 'Warwick Business School', 'Corporate Relations Manager', '15-juin-16']
# ['Akan', 'Ukwak', '', 'Multiple', 'Project Manager', '14-juin-16']
# ['James', 'Nethercott', '', 'Regulatory Finance Solutions', 'Group Head Marketing', '13-juin-16']
# ['Alessandro', 'Santini', '', 'Accenture', 'Principal Director, Intelligent Engineering Services', '12-juin-16']
# ['Jonathan', 'Taylor', '', 'x-tention Informationstechnologie GmbH', 'Managing Director (UK&I)', '12-juin-16']
# ['Jade Wendy', 'Brooks', '', 'Loughborough University School of Business and Economics', 'Lecturer of Innovation and International Management', '12-juin-16']
# ['Harjit', 'Dewar ', '', 'Shell', 'Operational Risk and Security Lead', '11-juin-16']
# ['Marina Zouni', 'Hallworth CEng MBA', '', 'The Lighthouse Furniture Project', 'Trustee and Director', '11-juin-16']
# ['Denise', 'Mullen', '', 'HealthShare NSW', 'Strategic Procurement and Partnering Consultant', '11-juin-16']
# ['Isa', 'Truchet', '', 'Accenture', 'Technology Consultant Manager', '11-juin-16']
# ['Isaac', 'Vaghefi', '', 'Pace University', 'Assistant Professor of Information Systems', '20-mars-16']
# ['Alex', 'Serban', '', 'Road Grand Tours', 'CEO, CTO', '20-mars-16']
# ['Stuart', 'Towns', '', 'KPMG UK', 'Business Intelligence Consultant', '12-mars-16']
# ['Jana', 'MandovÃ¡', '', 'Darktrace', 'Cyber Technology Specialist', '05-mars-16']
# ['Shammi', 'Shah', '', 'GiveMeTap', 'Customer Engagment Lead', '07 Feb 2016']
# ['Alex', 'Millar', '', 'National Grid', 'Graduate Buyer ', '23-janv-16']
# ['Alain', 'Fortier', '', 'Revenu Québec', 'Advisor Enterprise Architecture', '04-janv-16']
# ['Victoria', 'Rudenko', '', 'Self-employed', 'Digital Marketing Strategist', '26-nov-15']
# ['Philipp', 'Hukal', '', 'Copenhagen Business School', 'Assistant Professor', '26-oct-15']
# ['Dr Bo', 'Kelestyn FHEA', '', 'University of Warwick', 'Student Surveys Analyst', '17-oct-15']
# ['Robin', 'Som', '', 'Lewisham and Greenwich NHS Trust', 'Surgical Registrar', '30 Aug 2015']
# ['Mostafa', 'Mesgari', '', '', '', '02 Aug 2015']
# ['Marc Christopher', 'Held', '', 'GE', 'Commercial Proposal Director', '18-juil-15']
# ['Dovile', 'Sniokaite', '', 'Swedbank', 'Accounting & Financial Reporting (IFRS) Expert, Group Finance', '13-juil-15']
# ['Christina', 'Murias', '', 'Herxide', 'Land Acquisition Manager', '19-juin-15']
# ['Shaurya', 'Mehta', '', 'Metcon India Realty & Infrastruture Pvt. Ltd.', 'Director', '17-juin-15']
# ['David', 'McCafferty', '', 'Kabanski Associates Ltd', 'Managing Director', '17-juin-15']
# ['Joshua', 'Tedam', '', 'Cognizant', 'Enterprise Architect - Consulting', '17-juin-15']
# ['Dr Nicola', 'Burgess', '', 'Warwick Business School', 'Associate Professor of Operations Management', '30 Apr 2015']
# ['Mario', 'Ramotar, PhD', '', 'CWT', 'Senior UX Researcher', '07 Apr 2015']
# ['Ana', 'Ortiz de Guinea Lopez de Arana', '', 'Deusto Business School', 'Associate Professor - Director of the Digital Environments Management Program', '01 Apr 2015']
# ['Natalia', 'Levina', '', 'New York University', 'Full Professor, Toyota Motors Corp. Term Chair', '31-mars-15']
# ['Sanjana', 'Ramamurthy', '', 'EY', 'Manager', '31-mars-15']
# ['Mathew', 'Tuvesson', '', 'Checkout.com', 'Senior Product Manager', '29-mars-15']
# ['Andrew', 'Thomas', '', 'Yopa Property', 'Front-end developer', '10-mars-15']
# ['Leanne', 'Allen', '', 'KPMG UK', 'Director', '02-mars-15']
# ['Nick', 'Blewden', '', "Lloyd's", 'Head of Data Product Development', '25 Feb 2015']
# ['Xing', 'Yu', '', 'PwC SDC Shanghai', 'Manager', '18 Feb 2015']
# ['Heidi', 'Emami', '', 'McGill University', 'Associate Registrar, Academic Records and Examinations', '16-janv-15']
# ['Mara', 'Ivan', '', 'Apple', 'Manager, Data Systems', '09-janv-15']
# ['Andra', 'Serban', '', 'Virginia Commonwealth University - School of Business', 'Assistant Professor', '05 Dec 2014']
# ['Dr. Hari Suman', 'Naik', '', 'adidas', 'Senior Project Manager', '24-nov-14']
# ['Laura', 'Winer', '', 'McGill University', 'Director, Teaching and Learning Services', '18-nov-14']
# ['Juliane', 'Reinecke', '', "King's Business School", 'Professor of International Management & Sustainability', '05-nov-14']
# ['Alexie', 'Labouze-Nasica, Ph.D.', '', 'École des sciences de la gestion (ESG UQAM)', 'Professor of Strategic Management', '27-oct-14']
# ['Paolo', 'Quattrone', '', 'Harbour of Cultures', 'Vice President', '22-oct-14']
# ['Minwoo', 'Lee', '', 'University of Houston, Conrad N. Hilton College of Hotel and Restaurant Management', 'Assistant Professor', '02-oct-14']
# ['Mohammad', 'Nikoofal', '', 'Ryerson University, Ted Rogers School of Management', 'Assistant Professor of Operations and Supply Chain Management', '11-sept-14']
# ['Gregory', 'Vial', '', 'HEC Montréal', 'Assistant Professor of Information Technology', '09-sept-14']
# ['Elena', 'Patulli', '', 'McGill University', 'Senior Functional Business Analyst', '21 Aug 2014']
# ['Adam', 'Finkelstein', '', 'McGill University', 'Associate Director, Learning Environments, Teaching and Learning Services', '18 Aug 2014']
# ['Bo', 'Yu', '', 'Rowe School of Business, Dalhousie University', 'Assistant Professor', '12 Aug 2014']
# ['Mathieu', 'Templier', '', 'Université Laval', 'Associate Professor', '09 Aug 2014']
# ['Mariachiara', 'Restuccia', '', 'University of Sussex', 'Lecturer in Marketing', '24-juil-14']
# ['Alina', 'Dulipovici', '', 'HEC Montréal', 'Associate Professor', '22-juil-14']
# ['Frank', 'Babics', '', 'McGill University', 'Manager Graduate Admissions', '21-juil-14']
# ['Aleksi', 'Aaltonen', '', 'Temple University', 'Assistant Professor', '10-juil-14']
# ['Youngjin', 'Yoo', '', 'Case Western Reserve University - Weatherhead School of Management', 'Elizabeth M. and William C. Treuhaft Professor in Entrepreneurship', '31 May 2014']
# ['Hoda', 'Nasseri', '', 'Deloitte Consulting', 'Cyber Security Reporting and Analytics Project Manager', '12 May 2014']
# ['Hanieh', 'Moshki', '', 'PwC Canada', 'Manager, Cybersecurity and Privacy', '20 Apr 2014']
# ['Onook', 'Oh', '', 'University of Colorado Denver Business School', 'Assistant Professor', '10 Apr 2014']
# ['Joe', 'Nandhakumar', '', 'Warwick Business School', 'Professor of Information Systems', '02 Apr 2014']
# ['', '', '', '', '', '06-mars-14']
# ['Victoria', 'Grandury', '', 'Deloitte Canada', 'Manager - Cyber Risk', '13 Feb 2014']
# ['Elodie', 'Cheong Youne', '', 'ExxonMobil', 'Project Track Lead', '07 Feb 2014']
# ['IsraÃ«l', 'Fortin, Ph.D.', '', 'Indian Institute of Management Bangalore', 'Assistant Professor', '01 Feb 2014']
# ['Claire', 'Ingram Bogusz', '', 'University of Gothenburg', 'Postdoctoral Researcher', '02-janv-14']
# ['Anna', 'Karpovsky', '', 'Boston College Carroll School of Management', 'Assistant Professor of Practice', '02-janv-14']
# ['Jan', 'Damsgaard', '', 'Copenhagen Business School', 'Professor', '02-janv-14']
# ['Lauren', 'Rhue', '', 'Wake Forest University School of Business', 'Assistant Professor', '28 Dec 2013']
# ['Sumantra', 'Sarkar', '', 'School of Management, Binghamton University', 'Assistant Professor', '23 Dec 2013']
# ['Lena', 'Hylving', '', 'Halmstad University', 'Associate Professor', '16 Dec 2013']
# ['Quang Neo', 'Bui', '', 'Rochester Institute of Technology', 'Assistant Professsor', '14 Dec 2013']
# ['Stella', 'Pachidi', '', 'Cambridge Judge Business School', 'University Lecturer (Assistant Professor)', '14 Dec 2013']
# ['Ola', 'Henfridsson', '', 'University of Miami Business School', 'Professor of Business Technology', '14 Dec 2013']
# ['Elena', 'Karahanna', '', 'Terry College of Business, University of Georgia', 'Distinguished Research Professor and L. Edmund Rast Professor of Business', '13 Dec 2013']
# ['Anne-Marie', 'Croteau, PhD, CDir', '', 'Hydro-Québec', 'Board Member', '02 Dec 2013']
# ['Sergiu', 'Popescu', '', '', '', '04-nov-13']
# ['Gerald', 'Kane', '', 'Boston College - Wallace E. Carroll Graduate School of Management', 'Professor', '29-oct-13']
# ['Ron', 'Leisti', '', 'NetSuite', 'Principal Software Developer', '21-oct-13']
# ['Denise', 'Nahas', '', 'LightSpeed Retail', 'VP,  Customer Support', '18-oct-13']
# ['Kyung', 'Lee', '', 'Dalhousie University', 'Associate Professor', '14-sept-13']
# ['Saeed', 'Akhlaghpour', '', 'UQ Business School', 'Senior Lecturer', '09-sept-13']
# ['Rima', 'El-Khatib, PhD', '', 'Prince Mohammad Bin Fahd University', 'Assistant Professor', '07-sept-13']
# ['Julien', 'Meyer', '', 'Ryerson University', 'Assistant Professor', '05-sept-13']
# ['Benoit', 'Aubert', '', 'Dalhousie University', 'Director - Rowe School of Business', '22 Aug 2013']
# ['Forough', 'Karimi-Alaghehband', '', 'HEC Montréal', 'Instructional Designer', '12-juil-13']
# ['Shelagh', 'Pepper', '', 'Wilfrid Laurier University', 'Associate Registrar, Registrarial Services and Systems', '06-juil-13']
# ['Nermein', 'Gamal', '', 'McGill University', 'Assistant Registrar, Systems, Project and Change Management', '22-juin-13']
# ['Simon', 'Fulleringer', '', 'McGill University', 'Asset & Configuration Management Process Manager', '18-juin-13']
# ['PetruÈ›a', 'Popescu', '', 'Homeopetra SRL', 'Medic specialist MF', '18-juin-13']
# ['Chahin', 'Kordlouie DMD', '', 'Melville Dental Group', 'Dentist', '11-juin-13']
# ['Lorne', 'Wald', '', 'McGill University', 'Data Security Analyst', '11-juin-13']
# ['Mahmood', 'Shafeie Zargar', '', 'Vrije Universiteit Amsterdam / VU', 'Assistant Professor', '23 Apr 2013']
# ['Ghazaleh', 'Aghili', '', 'McGill University - Desautels Faculty of Management', 'Lecturer', '21 Apr 2013']
# ['Paul', 'Leonardi', '', 'UC Santa Barbara', 'Duca Family Professor of Technology Management', '13 Apr 2013']
# ['Brian', 'Pentland', '', 'Michigan State University', 'Professor', '13 Apr 2013']
# ['Kunsoo', 'Han', '', 'Desautels Faculty of Management, McGill University', 'Associate Professor', '03 Apr 2013']
# ['', '', '', '', '', '25 Feb 2013']
# ['Colin', 'Abbott', '', 'McGill University', 'IT Security Architect', '14 Feb 2013']
# ['Diego', 'Mastroianni, PhD', '', "Moody's Analytics", 'Director of Implementation Services', '06 Feb 2013']
# ['John', 'Kim', '', 'RBC Capital Markets', 'Data Strategist', '25-janv-13']
# ['', '', '', '', '', '24-janv-13']
# ['Andrew', 'Dias', '', 'McGill University', 'Technical Leader, Application Development', '23-janv-13']
# ['Louis-Clément', 'Schiltz ðŸ¤–ðŸš€', '', 'WEBOTIT', 'President', '17-janv-13']
# ['James', 'Denford', '', 'Royal Military College of Canada/Collège militaire royal du Canada', 'Dean, Faculty of Social Sciences and Humanities', '27 Dec 2012']
# ['', '', '', '', '', '24 Dec 2012']
# ['David J.', 'Stenason', '', 'Rempart Asset Management', 'Managing Director', '22-nov-12']
# ['José Carlos', 'Marques', '', 'Telfer School of Management at the University of Ottawa', 'Assistant Professor - Strategy, Corporate Responsibility and Sustainability', '21-nov-12']
# ['Daniel', 'Trotto', '', 'McGill University', 'BI Developer', '21-nov-12']
# ['Manon G.', 'Guillemette', '', 'Technopolys', 'Ambassador', '22-oct-12']
# ['Andrew', 'Burton-Jones', '', 'UQ Business School, The University of Queensland', 'Professor', '21-oct-12']
# ['Manju', 'Ahuja', '', "University of Louisville's College of Business", 'Professor and University Scholar', '19-oct-12']
# ['Brian', 'Arsenault', '', 'McGill University', 'Manager Enterprise Desktop Solutions', '01-oct-12']
# ['Rita M.', 'Benitez', '', 'UNFCCC', 'Associate Knowledge Management Officer', '05-sept-12']
# ['Deborah', 'Compeau', '', 'Washington State University - Carson College of Business', 'Senior Associate Dean for Faculty Affairs and Research', '25 Aug 2012']
# ['Thibaut', 'Coulon', '', 'École des sciences de la gestion (ESG UQAM)', 'Assistant Professor', '23 Aug 2012']
# ['Bill', 'Kennedy', '', 'US Overseas Private Investment Corporation (OPIC)', 'Director, Office of Accountability', '23 Aug 2012']
# ['Denisa', 'Voicu', '', 'Hager Group', 'LEAN SENIOR MANAGER (Member of Management Team)', '19-juil-12']
# ['Mohammad', 'Moeini', '', 'University of Sussex', 'Lecturer (Assistant Professor) in Information Systems', '17-juil-12']
# ['Mustapha', 'Cheikh-Ammar', '', 'Ivey Business School', 'Assistant Professor', '28-juin-12']
# ['Catherine', 'Marchand, Ph.D.', '', 'Centre for Health Services Studies', 'Senior Trial Manager for RISKIT-CJS', '15-juin-12']
# ['Josianne', 'Marsan', '', 'Université Laval', 'Full Professor', '15-juin-12']
# ['Eve', 'Lamargot', '', 'Lazaridis School of Business & Economics at Wilfrid Laurier University', 'Professeure adjointe (instructrice) en contrôle de gestion', '13-juin-12']
# ['Genevieve', 'Bassellier', '', 'McGill University', 'Associate Professor', '07-juin-12']
# ['Gruia', 'Pitigoi-Aron', '', 'The Trade Desk', 'VP, Product', '15 May 2012']
# ['Nolywé', 'Delannon', '', 'Université Laval', 'Assistant Professor', '22 Apr 2012']
# ['Jui', 'Ramaprasad', '', 'McGill University - Desautels Faculty of Management', 'Associate Professor', '22 Apr 2012']
# ['Joleen', 'Khoury', '', 'Caisse de dépôt et placement du Québec (CDPQ)', 'Manager - Security Architecture, Analytics & Controls', '12 Apr 2012']
# ['Elisa', 'Gagnon, Ph.D', '', "Williams School of Business at Bishop's University", 'Assistant Professor', '03 Apr 2012']
# ['Kindness', 'Keong, MBA, PMP', '', 'Jardine Matheson', 'Manager, Innovation', '02-mars-12']
# ['Elan', 'Weinstock', '', 'Amazon', 'Software Development Engineer', '10 Feb 2012']
# ['Azadeh', 'Savoli', '', 'IÉSEG School of Management', 'Assistant Professor', '26-janv-12']
# ['Carlos A.', 'Rodriguez', '', 'INCAE Business School', 'Assistant Professor of Strategy and Organizations', '15 Dec 2011']
# ['Dan', 'Pilat', '', 'The Decision Lab', 'Co-Founder, Managing Director', '15 Dec 2011']
# ['Marlous', 'Agterberg', '', 'KIN Center for Digital Innovation', 'Research and Valorisation Manager', '15 Dec 2011']
# ['Isla', 'Milne', '', 'McGill University', 'PhD Candidate, Strategy and Organization, Desautels Faculty of Management', '15 Dec 2011']
# ['Nada O.', 'Basir, PhD', '', 'University of Waterloo - Conrad Business, Entrepreneurship and Technology Centre', 'Assistant Professor - Strategic Management', '15 Dec 2011']
# ['Soha', 'Hawili', '', 'Concordia University', 'Academic Advisor', '15 Dec 2011']
# ['Jean-Francois', 'Belisle', '', 'Life House', 'Senior Director - Data Science & Revenue Management', '01 Dec 2011']
# ['Ali', 'Javed, PMP', '', 'Facebook', 'Business Operations Analyst - Infrastructure Business Operations', '30-nov-11']
# ['Yasser', 'Rahrovani', '', 'Ivey School of Business - The University of Western Ontario', 'Assistant Professor', '30-nov-11']
# ['Chris', 'Matthijsse', '', 'McGill University', 'Senior Analyst', '16-nov-11']
# ['Tia (Teodora)', 'Lazar', '', 'Endava', 'Lead Project Management Officer', '15-nov-11']
# ['Régis', 'Barondeau', '', 'École des sciences de la gestion (ESG UQAM)', 'Professor', '22 Feb 2011']
# ['Eric', 'Beaulieu', '', 'Solumax Consulting Services', 'Owner', '26-janv-11']
# ['Alain', 'Pinsonneault', '', 'McGill University', 'Professor', '12-oct-10']
# ['Russell', 'Seidle', '', 'Suffolk University', 'Assistant Professor', '07-oct-10']
# ['Kristin', 'Korim', '', 'Parliament of Canada', 'Functional Lead, Human Resources Management System Renewal and Change Management', '02-sept-10']
# ['Cristina', 'Tanasescu', '', 'VMware', 'Manager, Partner Organization, Mediterranean & Eastern Europe', '06 Aug 2010']
# ['Daniela', 'Thions', '', 'McKinsey & Company', 'Engagement Manager', '05 Aug 2010']
# ['Venu', 'Katikaneni', '', 'McGill', 'Programmer', '30-janv-10']
# ['Suzanne', 'Rivard', '', 'HEC Montreal', 'Professeur', '12 Dec 2009']
# ['Frederick', 'Le Page', '', 'Bell Business Markets', 'Project Executive', '27-nov-09']
# ['Animesh', 'Animesh', '', 'McGill University', 'Associate Professor', '08-oct-09']
# ['Hani', 'Safadi', '', 'University of Georgia - Terry College of Business', 'Assistant Professor', '17-sept-09']
# ['Stephan', 'Lukac', '', 'Best Buy Canada', 'Senior Marketing Manager', '31 Aug 2009']
# ['Mike', 'Deutsch', '', 'Kids Code Jeunesse', 'Director of Educational Development', '31 Aug 2009']
# ['Thierry', 'Mayrand', '', 'McGill University', 'Solutions Architect', '31 Aug 2009']
# ['Marc', 'Huffstickler', '', 'Texas A&M University', 'Software Application Developer', '02-juil-09']
# ['Sue', 'Reali', '', 'Bristol-Myers Squibb', 'Director, Information Systems', '13-juin-09']
# ['Salaheddin', 'Baki', '', 'Solutions Metrix - Certified CRM Partner (Microsoft, Oracle, Salesforce & SugarCRM)', 'Director Of Development', '11-juin-09']
# ['Jean Paul', 'Merymo', '', 'TD', 'AVP', '18 May 2008']
# ['Mario', 'Rossi', '', 'CAE', 'Manager, Market Pricing and Strategy (Product Management)', '16 May 2008']
# ['Gustavo', 'Mothe, MBA', '', 'IMC - Instituto Modelo de Cardiologìa Privado ', 'Project Leader, Process Quality and Continuous Improvement Management ', '25 Apr 2008']
# ['Christian', 'Caron', '', 'Google', 'Staff Software Engineer and Manager', '25 Apr 2008']
# ['Srdjan', 'Jovanovic', '', 'Pfizer', 'Manager Operational Excellence', '26-oct-07']
# ['Melanie', 'Wilson', '', 'Workplace Safety & Prevention Services', 'Organizational Development and Performance Specialist', '01-juil-07']
# ['Alexandra', 'Kapelos-Peters, PMP, CSM, MBA candidate', '', 'Stratenym', 'Co-Founder and Vice President, Chief Operating Officer', '08-mars-07']
# ['Thuy (Twee) ', 'Nguyen', '', 'North', 'Supplier Development Engineer', '07-mars-07']
# ['Alex', 'Mendelev', '', 'DoubleJump Games', 'CEO', '07-mars-07']
# ['Florin', 'Negoita', '', 'OntarioMD', 'Sr. Project Manager', '07-mars-07']
# ['Albina', 'Shapiro', '', 'SAP Labs', 'Product Owner', '17 Feb 2007']
# ['Sydney', 'Vasseur', '', 'Gemini Data Inc.', 'Business Development Representative EMEA', '24-nov-16']
# ['Brian', 'Lack', '', 'Simply Voting Inc.', 'President', '15 Dec 2011']
# ['Nolwen', 'Mahé', '', 'Alsago Inc.', 'Consultant, Agile governance', '02 Dec 2011']
# ['Marlene', 'Newton', '', 'Informatique Newton Inc.', 'Senior Project Manager', '11-juin-09']

# %% [markdown]
# Mettons tous ces éléments ensemble pour créer nos 6 listes, une par caractéristique. On voudra bien sûr passer par-dessus la première ligne qui contient le nom des caractéristiques ! On validera le tout en affichant le nombre d'éléments dans chaque liste, qui devrait selon tout vraisemblance être le même.

# %%
# Création de listes vides pour chaque colonne
first_name = []
last_name = []
email = []
company = []
position = []
connected_on = []

# On découpe chaque ligne, sauf la première qui se trouve à l'index 0
for i in range(1, len(connexions)):
    # On enlève les caractères superflus et on découpe autour de la séquence de caractères ","
    data = connexions[i].strip().split('","')
    
    # On modifie le premier élément en retirant le premier caractère #debarasse les guillumes au debut
    data[0] = data[0][1:]
    
    # On modifie le dernier élément en retirant le dernier caractère #debarasse les guillumes a la fin
    data[-1] = data[-1][:-1]
    
    # On ajoute les données dans la liste correspondant à la bonne colonne
    first_name.append(data[0])
    last_name.append(data[1])
    email.append(data[2])
    company.append(data[3])
    position.append(data[4])
    connected_on.append(data[5])

# On affiche la longueur des listes pour s'assurer que chacune contient le même nombre d'éléments.
print(len(first_name))
print(len(last_name))
print(len(email))
print(len(company))
print(len(position))
print(len(connected_on))
# Out:
# 292
# 292
# 292
# 292
# 292
# 292

# %% [markdown]
# ## Normaliser et compter les noms d’entreprise
#
# Nous voulons maintenant produire des statistiques sur le nombre de contacts provenant des mêmes organisations. Comme le nom des organisations est saisie par les utilisateurs, il est possible que des erreurs ou incohérences se soient introduites lors de la saisie. Il sera donc nécessaire de faire un peu de normalisation.
#
# - Par exemple, pour cette analyse des noms d’entreprise, nous voudrions :
#
#     - supprimer les suffixes possibles (p.ex., Inc./Inc/LLC/LLP/Corp./Corp);
#     - compter le nombre de contacts par organisation;
#     - afficher les organisations avec plus d'un contact.
#
# La liste des noms de compagnies se trouve dans la liste `company` que nous venons de construire.

# %% [markdown]
# Nous voulons réaliser de façon systématique un certain nombre de transformations, soit  :
#
# 1. supprimer les éléments non significatifs du nom des organisations,
# 2. effacer les données non significatives,
# 3. uniformiser l'orthographe de termes importants.
#
# Pour faciliter ce travail, on définira une fonction `filter_company` effectuant ces substitutions. Cette fonction appliquera l'ensemble des substitutions, spécifiées dans une liste, comme nous l'avons illustré à la __séance 4__ (sur les fonctions).
#
# Pour que cette fonction soit appliquée à toutes les valeurs d'une liste, on utilisera une boucle.

# %%
def filter_company(name): #clean (parce que on ne filte pas vraiment)
    
    # supprimer les espaces au début et à la fin du nom d'une entreprise
    string = name.strip()

    # Liste des transformations possibles du nom de l'entreprise
    transforms = [(', Inc.', ''), (', Inc', ''), (' Inc.', ''), (' Inc', ''),
                  (', inc.', ''), (', inc', ''), (' inc.', ''), (' inc', ''),
                  (', Corp.', ''), (', Corp', ''), (' Corp.', ''), (' Corp', ''),
                  (', LLC', ''), (', LLP', ''), (' LLC', ''), (' LLP', ''),
                  ('Montreal', 'Montréal')]

    for transform in transforms:
        
        # *transform : nous passons en paramètre la valeur à remplacer (p.ex. ', Inc.' )
        # et la valeur de remplacement (p.ex. '' )
        name = name.replace(*transform)
    
    return name

# %% [markdown]
# On applique ensuite ce filtre à tous les éléments de la liste. Pour faciliter le travail, nous allons créer une nouvelle liste contenant les données nettoyées.

# %%
# Initialisation de la liste
company_clean = []

# On applique la transformation à chaque nom de compagnie dans la liste 'company'
for item in company:
    
    # On applique le filtre en appelant la fonction filter_company(), précédemment définie
    filtered_c = filter_company(item)
    
    # On stocke la donnée nettoyée dans la nouvelle liste
    company_clean.append(filtered_c)

# On affiche la longueur du résultat pour s'assurer qu'on a le même nombre d'éléments
# entre la liste originale de compagnies et la liste nettoyée de compagnies
print(len(company_clean))


copmanies = [filter_company(comp) for comp in company]
# Out:
# 292

# %% [markdown]
# Une première analyse est de __compter le nombre de contacts provenant des diverses organisations__ mentionnées dans la liste des connexions. Pour y arriver, on doit d'abord compter le nombre de fois que chaque compagnie est mentionnée.
#
# Pour ce faire, nous allons construire un dictionnaire dont la clé sera le nom de la compagnie et la valeur, le nombre de fois que cette compagnie a été trouvée. Pour valider le résultat, nous allons faire la somme des décomptes. Cette somme devrait être égale au nombre d'éléments de la liste originale.
#
# __Attention!__ :
#
# - Il faut s'assurer que le nom existe déjà dans le dictionnaire. Lorsqu'on le trouve pour la première fois, on va __initialiser__ (c.-à-d., donner une valeur initiale) le compteur à 0.
# - Lorsqu'on rencontre un nom déjà présent, il faut __incrémenter__ (c.-à-dire, augmenter de 1) le nombre d'occurences.

# %%
# Création du dictionnaire vide
company_count = {}

# On traite chaque nom de compagnie se trouvant dans la liste company_clean
for name in company_clean:
    
    # On vérifie que cette compagnie est déjà présente ou non dans le dictionnaire
    # Attention ! Il faut utiliser la fonction get() sinon il y a une erreur d'exécution
    # La valeur n'est pas présente si get() retourne la valeur None
    if company_count.get(name) == None:
        
        # On crée une entrée dans le dictionnaire avec une clé item et, comme valeur, 
        # le décompte 0. On va l'incrémenter tout de suite après !
        company_count[name] = 0 

    # On incrémente le décompte dans notre dictionnaire, company_count {}:
    # nouveau décompte = ancien décompte + 1
    # pour chaque compagnie, la première fois, l'ancien décompte est 0 !
    company_count[name] = company_count[name] + 1

    
# juste de la vérification du nombre d'entreprises traitées
decompte = 0

for item in company_count:
    decompte = decompte + company_count[item]

print(decompte)
print(len(company))
# Out:
# 292
# 292

# %%
# Qu'est-ce que j'ai dans mon dictionnaire company_count {} ?
# Clés : noms des compagnies
# Valeurs : nombre des gens qui y travaillent
print(company_count)
# Out:
# {'Essilor Canada': 1, 'HEC Montréal': 20, 'CBC': 1, 'Darling Ingredients Germany Holding GmbH': 1, 'Key Lime Interactive': 1, 'Ivey Business School at Western University': 1, 'Université Laval': 4, 'Collège de Bois-de-Boulogne': 1, "CIUSSS de l'Estrie - CHUS": 1, 'Why-What-How Consulting': 1, 'Banque Nationale': 2, 'Amgen': 1, 'Warwick Business School': 4, 'National Research Council Canada / Conse
 1, 'Yopa Property': 1, "Lloyd's": 1, 'PwC SDC Shanghai': 1, 'Apple': 1, 'Virginia Commonwealth University - School of Business': 1, 'adidas': 1, "King's Business School": 1, 'École des sciences de la gestion (ESG UQAM)': 3, 'Harbour of Cultures': 1, 'University of Houston, Conrad N. Hilton College of Hotel and Restaurant Management': 1, 'Ryerson University, Ted Rogers School of Management': 1, 'Rowe School of Business, Dalhousie University': 1, 'Temple University': 1, 'Case Western Reserve University - Weatherhead School of Management': 1, 'Deloitte Consulting': 1, 'PwC Canada': 1, 'University of Colorado Denver Business School': 1, 'Deloitte Canada': 1, 'ExxonMobil': 1, 'Indian Institute of Management Bangalore': 1, 'University of Gothenburg': 1, 'Boston College Carroll School of Management': 1, 'Wake Forest University Scho ...

# %% [markdown]
# Pour afficher les données, on voudra trier les données du dictionnaire que nous venons de produire.
#
# __Attention!__ On ne peut pas garantir l'ordre des clés d'un dictionnaire. On peut par contre trier la liste des clés et accéder au dictionnaire dans l'ordre désiré. Il faut donc trouver une façon de trier les clés, mais en utilisant les valeurs du dictionnaire pour faire le tri. La solution est d'utiliser le paramètre `key` qui indique la fonction à utiliser pour effectuer le tri.
#
# De plus, on ne voudra afficher que les organisations avec __au moins 2 contacts__ et ne pas afficher lorsque la compagnie n'est pas mentionnée.

# %%
# On veut trier les clés du dictionnaire, company_count {}, par ordre décroissant de la
# valeur (nombre de gens qui y travaillent) associée à la clé (nom d'une compagnie) !

# sorted : les valeurs dans company_count {} ne sont pas triées par défaut, donc il faudra les trier
# company_count : le dictionnaire contenant les données
# __getitem__ : retourne la valeur associé à une clé dans le dictionnaire
# key : donne la fonction utilisée pour la clé de tri
# reverse=True : on veut en ordre du plus grand au plus petit
for item in sorted(company_count, key=company_count.__getitem__, reverse=True):
    #reverse= True --> descendre
    #key --> the variable that I want to sort for
    
    # s'il y a une clé (compagnie nommée) et que plus de deux personnes y travaillent, imprimez-la
    if item != '' and company_count[item] > 5:
        print("{0} : {1}".format(item,company_count[item]))
# Out:
# HEC Montréal : 20
# McGill University : 19

# %% [markdown]
# ## Normaliser et compter les noms de postes
#
# La même approche que celle utilisée pour normaliser les noms d’entreprises peut être utilisée pour normaliser les noms de postes. Cependant, cette normalisation est plus complexe que la normalisation des noms d’entreprises en raison du __caractère variable de la nomenclature des titres de poste__. Par exemple, observez les noms de postes suivants :
#
# - __Software engineer__, aussi connu sous le nom : _software architect_, _system engineer_. ...
# - __Application programmer__, aussi connu sous le nom : _system programmer_. ...
# - __Technical support__, aussi connu sous le nom : _IT support_, _technical consultant_. ...
# - etc.
#
# Bien qu'il soit possible de définir une liste d'alias ou d'abréviations associant des noms de postes tels "system engineer" à "software engineer", il peut ne pas être pratique de toujours définir ces listes, dans un cas général pour tous les domaines possibles.
#
# Cependant, il ne devrait pas être trop difficile de mettre en œuvre une solution qui traite les données au point où un expert puisse les examiner relativement facilement. Ce programme peut alors appliquer les règles de la même manière que l'expert l'aurait fait.
#
# BI Developer
# Ambassador
# Professor
# Professor and University Scholar
# Manager Enterprise Desktop Solutions
# Associate Knowledge Management Officer
# Senior Associate Dean for Faculty Affairs and Research
# Assistant Professor
# Director, Office of Accountability
# LEAN SENIOR MANAGER (Member of Management Team)
# Lecturer (Assistant Professor) in Information Systems
# Assistant Professor
# Senior Trial Manager for RISKIT-CJS
# Full Professor
# Professeure adjointe (instructrice) en contrôle de gestion
# Associate Professor
# VP, Product
# Assistant Professor
# Associate Professor
# Manager - Security Architecture, Analytics & Controls
# Assistant Professor
# Manager, Innovation
# Software Development Engineer
# Assistant Professor
# Assistant Professor of Strategy and Organizations
# Co-Founder, Managing Director
# Research and Valorisation Manager
# PhD Candidate, Strategy and Organization, Desautels Faculty of Management
# Assistant Professor - Strategic Management
# Academic Advisor
# Senior Director - Data Science & Revenue Management
# Business Operations Analyst - Infrastructure Business Operations
# Assistant Professor
# Senior Analyst
# Lead Project Management Officer
# Professor
# Owner
# Professor
# Assistant Professor
# Functional Lead, Human Resources Management System Renewal and Change Management
# Manager, Partner Organization, Mediterranean & Eastern Europe
# Engagement Manager
# Programmer
# Professeur
# Project Executive
# Associate Professor
# Assistant Professor
# Senior Marketing Manager
# Director of Educational Development
# Solutions Architect
# Software Application Developer
# Director, Information Systems
# Director Of Development
# AVP
# Manager, Market Pricing and Strategy (Product Management)
# Project Leader, Process Quality and Continuous Improvement Management
# Staff Software Engineer and Manager
# Manager Operational Excellence
# Organizational Development and Performance Specialist
# Co-Founder and Vice President, Chief Operating Officer
# Supplier Development Engineer
# CEO
# Sr. Project Manager
# Product Owner
# Business Development Representative EMEA
# President
# Consultant, Agile governance
# Senior Project Manager

# %% [markdown]
# On constate que certains de ces postes sont en fait une liste de postes, séparés par une barre verticale `|`, une barre oblique `/` ou un plus `+`. On voudrait donc modifier notre liste pour que ces différents titres soient associés au contact correspondant. On utilisera une liste de liste que l'on appellera `position_matrix`! Chaque élément de la liste `position_matrix` contiendra la liste des postes associés à un contact donné.
#
# L'idée ici est de découper le titre en une liste de titres lorsque les caractères `|`, `/` ou `+` sont présents. Si aucun de ces caractères n'est présent, la liste ne contiendra qu'un seul élément.
#
# Voici la recette à utiliser pour faire cette transformation.
#
# Tout d'abord, on veut créer une nouvelle liste qui contiendra la valeur actuelle, mais à l'intérieur d'une liste.

# %%
# On crée la liste des listes de postes
position_matrix = []

# On ajoute un élément pour le texte des postes associés à chaque contact
for item in position:
    # La valeur ajoutée est l'ancien texte, placé dans une liste!
    position_matrix.append( [ item.strip() ])

# On affiche le premier élément et le nombre d'éléments de la liste originale
print(position[0])
print(len(position))

# On affiche le premier élément et le nombre d'éléments de la nouvelle liste
print(position_matrix[0])
print(len(position_matrix))
# Out:
# Chef Partenariat d'affaires RH/HRBP Manager
# 292
# ["Chef Partenariat d'affaires RH/HRBP Manager"]
# 292

# %% [markdown]
# Définissons une fonction qui pourra faire l'expension sur un caractère quelconque. Par exemple en prenant `"Chef Partenariat d'affaires RH / HRBP Manager"` et le séparer en `'Chef Partenariat d'affaires RH', 'HRBP Manager'`.

# %%
def expand_on_char(matrice, char):
    # On crée une liste temporaire
    temp = []

    # On traite toutes les listes de poste dans la liste position_matrix
    for plist in matrice:
        # On crée une sous-liste temporaire
        temp2 = []
        # On traite chaque élément de plist
        for p in plist:
            # On traite chaque élément obtenu en faisant la séparation sur le caractère de séparation
            for x in p.split(char):
                temp2.append( x.strip() )

        temp.append(temp2)
    
    return temp

# %% [markdown]
# Commençons la transformation avec le caractère `|`. On veut faire le découpage de chaque élément de la liste de poste sur le caractère `|`. On appelle notre méthode avec ce caractère.

# %%
# On fait l'expension de la liste avec la fonction expand_on_char
position_matrix = expand_on_char(position_matrix, "|")

# On affiche les premiers éléments qui contiennent un |, / ou + et le nombre d'éléments de la liste originale
print(position[0])
print(position[1])
print(position[5])
print(len(position))

# On affiche les premiers éléments qui contiennent un |, / ou + et le nombre d'éléments de la nouvelle liste
print(position_matrix[0])
print(position_matrix[1])
print(position_matrix[5])
print(len(position_matrix))
# Out:
# Chef Partenariat d'affaires RH/HRBP Manager
# Lecturer | Database Management Course
# UX Researcher @ Google + Senior Quantitative Researcher @ KLI
# 292
# ["Chef Partenariat d'affaires RH/HRBP Manager"]
# ['Lecturer', 'Database Management Course']
# ['UX Researcher @ Google + Senior Quantitative Researcher @ KLI']
# 292

# %% [markdown]
# Poursuivons avec la transformation avec les caractères `/` et `+`.

# %%
# On fait l'expension de la liste avec la fonction expand_on_char
position_matrix = expand_on_char(position_matrix, "/")
position_matrix = expand_on_char(position_matrix, "+")

# On affiche les premiers éléments qui contiennent un |, / ou + et le nombre d'éléments de la liste originale
print(position[0])
print(position[1])
print(position[5])
print(len(position))

# On affiche les premiers éléments qui contiennent un |, / ou + et le nombre d'éléments de la nouvelle liste
print(position_matrix[0])
print(position_matrix[1])
print(position_matrix[5])
print(len(position_matrix))
# Out:
# Chef Partenariat d'affaires RH/HRBP Manager
# Lecturer | Database Management Course
# UX Researcher @ Google + Senior Quantitative Researcher @ KLI
# 292
# ["Chef Partenariat d'affaires RH", 'HRBP Manager']
# ['Lecturer', 'Database Management Course']
# ['UX Researcher @ Google', 'Senior Quantitative Researcher @ KLI']
# 292

# %% [markdown]
# Maintenant que la liste des postes est obtenue, on peut en faire l'affichage avec le nom de la personne qui occupe ses postes.

# %%
# On passe à travers tous les éléments des deux listes.
for i in range(0,len(first_name)):
    # On affiche les données pour un contact
    # La fonction join permet de faire un bel affichage de la liste de poste associée à un contact
    print("{0} {1} : {2}".format(first_name[i], last_name[i], ", ".join(position_matrix[i])))
# Out:
# Mélanie Dénommée : Chef Partenariat d'affaires RH, HRBP Manager
# Justine Authier, MSc : Lecturer, Database Management Course
# Elodie Champoux : Première Analyste Intelligence d'Affaires, Senior Business Intelligence Analyst
# Jean Talbot : Professeur titulaire, Full Professor
# Karsten Herr : Technical Director Germany, CTO
# Mina Rohani : UX Researcher @ Google, Senior Quantitative Researcher @ KLI
# Thierry Mayrand : Solutions Architect
# Marc Huffstickler : Software Application Developer
# Sue Reali : Director, Information Systems
# Salaheddin Baki : Director Of Development
# Jean Paul Merymo : AVP
# Mario Rossi : Manager, Market Pricing and Strategy (Product Management)
# Gustavo Mothe, MBA : Project Leader, Process Quality and Continuous Improvement Management
# Christian Caron : Staff Software Engineer and Manager
# Srdjan Jovanovic : Manager Operational Excellence
# Melanie Wilson : Organizational Development and Performance Specialist
# Alexandra Kapelos-Peters, PMP, CSM, MBA candidate : Co-Founder and Vice President, Chief Operating Officer
# Thuy (Twee)  Nguyen : Supplier Development Engineer
# Alex Mendelev : CEO
# Florin Negoita : Sr. Project Manager
# Albina Shapiro : Product Owner
# Sydney Vasseur : Business Development Representative EMEA
# Brian Lack : President
# Nolwen Mahé : Consultant, Agile governance
# Marlene Newton : Senior Project Manager

# %% [markdown]
# Nous pouvons maintenant effectuer __le même genre de nettoyage et d'analyse de fréquence__ que celle réalisée pour les organisations. Ici, nous devrons normaliser les titres plutôt que les noms de compagnie. On se rappellera que la liste des titres est en fait une liste de listes de titres.
#
# Définissons d'abord une fonction pour filter les titres de poste.

# %%
def filter_position(x):

    # supprimer les espaces au début et à la fin du nom d'un poste
    string = x.strip()

    # Liste des transformations possibles dans le nom d'un poste
    transforms = [
        ('Sr.', 'Senior'), ('Sr', 'Senior'),
        ('Jr.', 'Junior'), ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('AVP', 'Associate Vice President'),
        ('PHD', 'PhD'),
        ('Phd', 'PhD'),
        ('nan', ''),
        ('VP', 'Vice President'),
        ('Software architect','Software engineer'), ('System engineer','Software engineer'),
        ('System programmer','Application programmer'),
        ('professor', 'Professor'),
    ]

    # *transform : nous passons en paramètre la valeur à remplacer (p.ex. ', Sr.' )
    # et la valeur de remplacement (p.ex. 'Senior' )
    for transform in transforms:
        string = string.replace(*transform)
    
    return string

# %% [markdown]
# On peut maintenant appliquer cette méthode à l'ensemble des titres.

# %%
# Initialisation de la liste
position_clean = []

# On applique la transformation à chaque liste de titres
for plist in position_matrix:
    # On applique la transformation à chaque titre d'une liste
    
    plist_clean = []
    for p in plist:
        # On applique le filtre
        filtered_p = filter_company(p)

        # On stocke la donnée filtrée dans la nouvelle liste
        plist_clean.append(filtered_p)
        
    # On ajoute cette liste à la liste globale
    position_clean.append(plist_clean)

# On affiche la longueur du résultat pour s'assurer qu'on a le même nombre d'éléments
print(len(position_clean))
# Out:
# 292

# %% [markdown]
# Nous déterminons la fréquence des noms de poste de façon similaire à la fréquence des noms de compagnies, tout en considérant que nous avons une liste de listes! Ici par contre, nous ne pourront pas valider que notre processus fonctionne en calculant le décompte du nombre de postes. __Pourquoi est-ce le cas ?__

# %%
# Création du dictionnaire vide
position_count = {}

# On traite toutes les listes de titres de postes
for plist in position_matrix:

    # On traite chaque poste
    for p in plist:

        # On vérifie que ce titre est déjà présent ou non dans le dict
        # Attention! Il faut utiliser la fonction get() sinon il y a une erreur d'exécution
        # La valeur n'est pas présente si get() retourne la valeur None
        if position_count.get(p) == None:
            # On crée une entrée dans le dict avec le décompte à 0
            # On va l'incrémenter tout de suite après!
            position_count[p] = 0

        # On incrémente le décompte : nouveau décompte = ancien décompte + 1
        # La première fois, l'ancien décompte est 0!
        position_count[p] = position_count[p] + 1

# On veut trier les clés du dict par ordre décroissant de la valeur associée à la clé!
# le paramètre reverse=True indique qu'on veut en ordre du plus grand au plus petit.
# le paramètre key donne la fonction utilisée pour la clé de tri
# la fonction __getitem__ utilisée ici retourne l'item associé à une clé dans le dict
for p in sorted(position_count, key=position_count.__getitem__, reverse=True):
    print("{0} : {1}".format(p, position_count[p]))
# Out:
# Assistant Professor : 23
# Associate Professor : 12
#  : 10
# Professor : 7
# Assistant Professor of Information Systems : 3
# Lecturer : 2
# Full Professor : 2
# Owner : 2
# Senior Analyst : 2
# Postdoctoral Researcher : 2
# Lecturer (Assistant Professor) in Information Systems : 2
# Director : 2
# Managing Director : 2
# Manager : 2
# Senior Project Manager : 2
# President : 2
# Chef Partenariat d'affaires RH : 1
# HRBP Manager : 1
# Database Management Course : 1
# Première Analyste Intelligence d'Affaires : 1
# Senior Business Intelligence Analyst : 1
# Professeur titulaire : 1
# Technical Director Germany : 1
# CTO : 1
# UX Researcher @ Google : 1
# Senior Quantitative Researcher @ KLI : 1
# Visiting Professor : 1
# Faculty in Financial Technologies (FinTech) : 1
# Associate professor : 1
# Professeure agrégée : 1
# Enseignant département d'informatique : 1
# Teacher : 1
# Resident Physician : 1
# Médecin Résident : 1
# Independent Consultant : 1
# Developer IBM WebSphere Portal : 1
# Executive Biopharmaceutical Representative - Rheumatology : 1
# Dermatology : 1
# Group Coordinator : 1
# Doctoral Candidate : 1
# Data Scientist : 1
# Chargée de cours - Management Interculturel : 1
# Visiting Lecturer : 1
# Phd Candidate : 1
# Web Strategist, Partner : 1
# Venture Recruiter : 1
# Projet supervisé de maîtrise - science des données : 1
# Product Manager : 1
# Business Transformation Consultant: Talent & Mobilisation : 1
# Head of Legal, Europe : 1
# Head of Business Transformation : 1
# Director, Department of Information Technologies : 1
# Member of Strategic Design Panel : 1
# Deputy Programmes Manager : 1
# MBA Consultancy Project : 1
# Director of Supply Chain Planning : 1
# Risk and Compliance Director : 1
# Head of Customer Operations : 1
# Formateur et consultant en TI : 1
# Incoming Graduate Cyber Security Engineer : 1
# Directrice - Direction de l'apprentissage et de l'innovation pédagogique : 1
# Marketing Data Analyst, E-Commerce : 1
# Stagiaire en analytique, AI & Marketing : 1
# Notaire, conseillère juridique et médiatrice engagée : 1
# Conseiller Principal - Personnalisation des cartes : 1
# Watson IoT and Industry 4.0 Consultant : 1
# Technology Consymtant : 1
# Sub Unit Head- Retail Branch Control Unit, Corporate Office, : 1
# Editorial Board Member : 1
# Trading room manager : 1
# Kronos Junior Consultant : 1
# Auxiliaire d'enseignement en Technologies de l'Information : 1
